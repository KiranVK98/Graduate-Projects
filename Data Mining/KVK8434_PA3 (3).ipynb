# %% [markdown]
# # PA 3: Association Analysis - Apriori Algorithm

# %% [markdown]
# ## Student Details
#
# Student Name and ID:

# %%
#NAME: KIRAN VENKATESH KULKARNI, ID: 1001848434
#NAME: VIJETHA SHENOY BADIADKA, ID: 1001822855

# %% [markdown]
# ## Submission Instructions
#
#
# Step 1: Rename this file to 'yourNetID_PA3.ipnyb' and the report file to 'yourNetID_PA3.pdf' <br>
#
# Step 2: Upload all the document separately onto canvas  <br>**Not in a zip file. 20 points will be deducted if you don't follow the instruction**  <br>
# Note: Your submission should include ONLY the following files: <br>
#     * apriory.py  <br>
#     * yourNetID_PA3.ipynb  <br>
#     * yourNetID_PA3.pdf  <br>
#     * dataset.csv  <br>
#     * toyDS.csv <br>

# %% [markdown]
# ## Programming Assignment Details
#
# Before you start:
# - Note that this is an individual assignment.
# - Be familiar with the algorithm and with the dataset.
# - If you use external sources make sure that you cite them, and be specific!
# - Make sure that your code is running before you upload your submission file. TA will not debug your code.
# - Start early!
#
#
# For this assignment, you will have to use:
# * Jupyter notebook,
# * the 'Random Shopping cart' dataset [01],
# * and the Apriori Algorithm (apriory.py)[02]. Note that the apriory.py file is modified to run with Python 3.

# %% [markdown]
# ## ** Do Not Delete the Above Cell** <br>
# 10 points will be deducted if the instructions are not followed

# %% [markdown]
# ## - - - - - - - - - - - - - - - - - - - - - - - SOLUTION - - - - - - - - - - - - - - - - - - - - - - -

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# Import your Libraries

import pandas as pd
from pandas import Series, DataFrame
from collections import defaultdict

# %% [markdown]
# ### Task 1: DataSet Preprocess
# Before you start you need to modify your dataset 'dataset_group.csv' to look like the toyDS.csv.  Each transaction is at one line with a variable length.  Discard the date attribute (1st attribute) from your dataset.  For example, in your dataset transaction#4 should look like:
#
#     cereals,juice,lunch meat,soda,toilet paper,all-purpose
#
# Export your modified dataset in a file named 'dataset.csv'.
#
# Use pandas to Read and Print the first 7 transactions of the 'dataset.csv'.

# %%
# # # # # # # # #  Code for Task 1 # # # # # # # # #
# Preprocessing to get the dataframe in given format
 
df = pd.read_csv('dataset_group.csv')
df.head()
df.columns = ['Date','TransId','Item']
df.head()
df.drop('Date', axis =1 , inplace = True)
df.head()
# Out:
#    TransId           Item
# 0        1           pork
# 1        1  sandwich bags
# 2        1     lunch meat
# 3        1   all- purpose
# 4        1          flour

# %%
# # #  Solution  # # #

transactions = df.to_records(index = False)
result = list(transactions)

dic = defaultdict(list)

for i, j in result:
    dic[i].append(j)

f = open('dataset.csv','w')

for k, v in dic.items():
    f.write(','.join(v))
    f.write('\n')

f.close()

# %%
df = pd.DataFrame()

with open('dataset.csv', 'r') as f:
    for line in f:
        df = pd.concat( [df, pd.DataFrame([tuple(line.strip().split(','))])], ignore_index=True )

df.head(7)
# Out:
#                   0              1           2             3             4   \
# 0               pork  sandwich bags  lunch meat  all- purpose         flour
# 1       toilet paper        shampoo   hand soap       waffles    vegetables
# 2               soda           pork        soap     ice cream  toilet paper
# 3            cereals          juice  lunch meat          soda  toilet paper
# 4    sandwich loaves          pasta   tortillas         mixes     hand soap
# 5  laundry detergent   toilet paper        eggs  toilet paper    vegetables
# 6   individual meals   paper towels   tortillas    vegetables          milk
#
#              5                             6                             7   \
# 0          soda                        butter                    vegetables
# 1       cheeses                         mixes                          milk
# 2  dinner rolls                     hand soap               spaghetti sauce
# 3  all- purpose                           NaN                           NaN
# 4  toilet paper                    vegetables                    vegetables
# 5        bagels  dishwashing liquid/detergent                       cereals
# 6     ice cream                         juice  dishwashing liquid/detergent
#
#               8                  9   ...               24       25  \
# 0           beef      aluminum foil  ...              NaN      NaN
# 1  sandwich bags  laundry detergent  ...              NaN      NaN
# 2           milk            ketchup  ...  spaghetti sauce     pork
# 3            NaN                NaN  ...              NaN      NaN
# 4   paper towels         vegetables  ...     all- purpose     soda
# 5   paper towels  laundry detergent  ...  spaghetti sauce  ketchup
# 6           soap      sandwich bags  ...              NaN      NaN
#
#              26       27    28          29          30   31   32   33
# 0           NaN      NaN   NaN         NaN         NaN  NaN  NaN  NaN
# 1           NaN      NaN   NaN         NaN         NaN  NaN  NaN  NaN
# 2    vegetables  cheeses  eggs  vegetables  vegetables  NaN  NaN  NaN
# 3           NaN      NaN   NaN         NaN         NaN  NaN  NaN  NaN
# 4        yogurt      NaN   NaN         NaN         NaN  NaN  NaN  NaN
# 5  all- purpose     milk   NaN         NaN         NaN  NaN  NaN  NaN
# 6           NaN      NaN   NaN         NaN         NaN  NaN  NaN  NaN
#
# [7 rows x 34 columns]

# %% [markdown]
# ### Task 2: Run apriory.py and Evaluate Results
#
# In this task, you have to find how you will be able to execute and print apriory results by making use only the apriory.py. In other words "DO NOT USE ANY OTHER LIBRARY FOR TASK 2!!!".
#
# (*) For those that are not familiar with python and coding this could be a quite demanding task.
#
#
# You will have to execute apriori algorithm "3" times for different combinations of support and confidence.
# Print the results of apriory for 'dataset.csv' by making use ONLY the provided methods.
#
# Do not forget to add your reasoning (explain the result outcome) at the top of each case in a nice and readable way.
#
# You are allowed to use the python print method to print your results. DO NOT add your reasoning as comments.

# %%
print ('# # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #') 
print ('Case 1 (minimum support= 0.15 and minimum confidence=0.6)')
print ('Case 1 Reasoning:')
print ('Case 1 Output:')
! python apriori.py -f DATASET.csv -s 0.15 -c 0.6
# Out:
# # # # # # # # # #  Code for Task 2, Case:1 # # # # # # # # #
# Case 1 (minimum support= 0.15 and minimum confidence=0.6)
# Case 1 Reasoning:
# Case 1 Output:
#
# ------------ITEMS-----------------
# item: ('dinner rolls', 'toilet paper') , 0.150
# item: ('sandwich loaves', 'spaghetti sauce') , 0.150
# item: ('shampoo', 'ice cream') , 0.150
# item: ('pork', 'cheeses') , 0.150
# item: ('flour', 'mixes') , 0.150
# item: ('cereals', 'butter') , 0.150
# item: ('shampoo', 'sandwich loaves') , 0.150
# item: ('fruits', 'soda') , 0.150
# item: ('pork', 'beef') , 0.150
# item: ('fruits', 'all- purpose') , 0.150
# item: ('sandwich loaves', 'aluminum foil') , 0.150
# item: ('pork', 'sandwich bags') , 0.150
# item: ('fruits', 'paper towels') , 0.150
# item: ('shampoo', 'soda') , 0.150
# item: ('soda', 'mixes') , 0.150
# item: ('pork', 'cereals') , 0.150
# item: ('bagels', 'all- purpose') , 0.150
# item: ('butter', 'spaghetti sauce') , 0.150
# item: ('cheeses', 'juice') , 0.150
# item: ('sandwich bags', 'paper towels') , 0.150
# item: ('cheeses', 'vegetables', 'eggs') , 0.150
# item: ('pasta', 'sugar') , 0.151
# item: ('cereals', 'all- purpose') , 0.151
# item: ('sandwich bags', 'aluminum foil') , 0.151
# item: ('pasta', 'milk') , 0.151
# item: ('shampoo', 'eggs') , 0.151
# item: ('bagels', 'sugar') , 0.151
# item: ('flour', 'soap') , 0.151
# item: ('shampoo', 'soap') , 0.151
# item: ('pork', 'yogurt') , 0.151
# item: ('sugar', 'eggs') , 0.151
# item: ('pork', 'eggs') , 0.151
# item: ('cheeses', 'paper towels') , 0.151
# item: ('shampoo', 'ketchup') , 0.151
# item: ('shampoo', 'pasta') , 0.151
# item: ('laundry detergent', 'vegetables', 'cereals') , 0.151
# item: ('vegetables', 'cereals', 'eggs') , 0.151
# item: ('tortillas', 'milk') , 0.152
# item: ('shampoo', 'all- purpose') , 0.152
# item: ('bagels', 'butter') , 0.152
# item: ('coffee/tea', 'milk') , 0.152
# item: ('sugar', 'dishwashing liquid/detergent') , 0.152
# item: ('fruits', 'eggs') , 0.152
# item: ('pork', 'waffles') , 0.152
# item: ('shampoo', 'individual meals') , 0.152
# item: ('all- purpose', 'milk') , 0.152
# item: ('hand soap', 'mixes') , 0.152
# item: ('all- purpose', 'mixes') , 0.152
# item: ('dinner rolls', 'butter') , 0.152
# item: ('bagels', 'coffee/tea') , 0.152
# item: ('paper towels', 'yogurt') , 0.152
# item: ('laundry detergent', 'individual meals') , 0.152
# item: ('dishwashing liquid/detergent', 'tortillas') , 0.152
# item: ('pasta', 'bagels') , 0.152
# item: ('waffles', 'butter') , 0.152
# item: ('flour', 'coffee/tea') , 0.152
# item: ('toilet paper', 'spaghetti sauce') , 0.152
# item: ('flour', 'dishwashing liquid/detergent') , 0.152
# item: ('toilet paper', 'sugar') , 0.152
# item: ('vegetables', 'aluminum foil', 'yogurt') , 0.152
# item: ('poultry', 'vegetables', 'sugar') , 0.152
# item: ('laundry detergent', 'bagels') , 0.153
# item: ('cheeses', 'sugar') , 0.153
# item: ('toilet paper', 'individual meals') , 0.153
# item: ('sandwich bags', 'coffee/tea') , 0.153
# item: ('laundry detergent', 'toilet paper') , 0.153
# item: ('shampoo', 'coffee/tea') , 0.153
# item: ('butter', 'mixes') , 0.153
# item: ('lunch meat', 'sandwich bags') , 0.153
# item: ('tortillas', 'yogurt') , 0.153
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.153
# item: ('individual meals', 'tortillas') , 0.153
# item: ('pork', 'dishwashing liquid/detergent') , 0.153
# item: ('ketchup', 'yogurt') , 0.153
# item: ('juice', 'dishwashing liquid/detergent') , 0.153
# item: ('pasta', 'tortillas') , 0.153
# item: ('sandwich bags', 'dinner rolls') , 0.153
# item: ('sandwich loaves', 'yogurt') , 0.153
# item: ('ketchup', 'sandwich loaves') , 0.153
# item: ('ketchup', 'paper towels') , 0.153
# item: ('coffee/tea', 'individual meals') , 0.153
# item: ('poultry', 'vegetables', 'yogurt') , 0.153
# item: ('sandwich bags', 'butter') , 0.154
# item: ('juice', 'milk') , 0.154
# item: ('shampoo', 'beef') , 0.154
# item: ('sandwich bags', 'fruits') , 0.154
# item: ('laundry detergent', 'pasta') , 0.154
# item: ('bagels', 'paper towels') , 0.154
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.154
# item: ('juice', 'all- purpose') , 0.154
# item: ('toilet paper', 'all- purpose') , 0.154
# item: ('lunch meat', 'mixes') , 0.154
# item: ('ice cream', 'mixes') , 0.154
# item: ('dinner rolls', 'hand soap') , 0.154
# item: ('coffee/tea', 'dishwashing liquid/detergent') , 0.154
# item: ('pork', 'all- purpose') , 0.154
# item: ('individual meals', 'eggs') , 0.154
# item: ('pork', 'ketchup') , 0.154
# item: ('ice cream', 'butter') , 0.154
# item: ('coffee/tea', 'paper towels') , 0.154
# item: ('shampoo', 'laundry detergent') , 0.154
# item: ('vegetables', 'dishwashing liquid/detergent', 'eggs') , 0.154
# item: ('butter', 'soda') , 0.155
# item: ('toilet paper', 'butter') , 0.155
# item: ('sandwich bags', 'bagels') , 0.155
# item: ('flour', 'aluminum foil') , 0.155
# item: ('individual meals', 'paper towels') , 0.155
# item: ('poultry', 'hand soap') , 0.155
# item: ('soap', 'paper towels') , 0.155
# item: ('coffee/tea', 'tortillas') , 0.155
# item: ('ketchup', 'all- purpose') , 0.155
# item: ('dinner rolls', 'beef') , 0.155
# item: ('laundry detergent', 'soap') , 0.155
# item: ('ketchup', 'spaghetti sauce') , 0.155
# item: ('waffles', 'mixes') , 0.155
# item: ('sandwich bags', 'yogurt') , 0.155
# item: ('flour', 'dinner rolls') , 0.155
# item: ('soap', 'sugar') , 0.155
# item: ('pork', 'bagels') , 0.155
# item: ('ketchup', 'dishwashing liquid/detergent') , 0.155
# item: ('juice', 'beef') , 0.155
# item: ('ketchup', 'beef') , 0.155
# item: ('sandwich loaves', 'cheeses') , 0.155
# item: ('beef', 'soda') , 0.155
# item: ('shampoo', 'paper towels') , 0.155
# item: ('beef', 'paper towels') , 0.155
# item: ('sandwich bags', 'mixes') , 0.155
# item: ('pasta', 'coffee/tea') , 0.155
# item: ('sugar', 'beef') , 0.155
# item: ('laundry detergent', 'juice') , 0.155
# item: ('fruits', 'spaghetti sauce') , 0.155
# item: ('ice cream', 'yogurt') , 0.155
# item: ('tortillas', 'soda') , 0.155
# item: ('dinner rolls', 'all- purpose') , 0.155
# item: ('pork', 'mixes') , 0.155
# item: ('juice', 'individual meals') , 0.155
# item: ('dinner rolls', 'bagels') , 0.155
# item: ('dinner rolls', 'paper towels') , 0.155
# item: ('shampoo', 'waffles') , 0.155
# item: ('poultry', 'vegetables', 'eggs') , 0.155
# item: ('waffles', 'paper towels') , 0.156
# item: ('cereals', 'juice') , 0.156
# item: ('bagels', 'beef') , 0.156
# item: ('cereals', 'soda') , 0.156
# item: ('paper towels', 'all- purpose') , 0.156
# item: ('ketchup', 'ice cream') , 0.156
# item: ('dinner rolls', 'milk') , 0.156
# item: ('toilet paper', 'tortillas') , 0.156
# item: ('shampoo', 'mixes') , 0.156
# item: ('flour', 'yogurt') , 0.156
# item: ('aluminum foil', 'spaghetti sauce') , 0.156
# item: ('sandwich bags', 'beef') , 0.156
# item: ('sandwich bags', 'ice cream') , 0.156
# item: ('ketchup', 'toilet paper') , 0.156
# item: ('coffee/tea', 'juice') , 0.156
# item: ('waffles', 'individual meals') , 0.156
# item: ('juice', 'soap') , 0.156
# item: ('ketchup', 'pasta') , 0.156
# item: ('laundry detergent', 'waffles') , 0.156
# item: ('paper towels', 'spaghetti sauce') , 0.156
# item: ('pork', 'juice') , 0.156
# item: ('lunch meat', 'flour') , 0.156
# item: ('cereals', 'sugar') , 0.156
# item: ('coffee/tea', 'toilet paper') , 0.156
# item: ('cheeses', 'milk') , 0.156
# item: ('ketchup', 'milk') , 0.156
# item: ('dinner rolls', 'soap') , 0.156
# item: ('poultry', 'vegetables', 'mixes') , 0.156
# item: ('dinner rolls', 'vegetables', 'eggs') , 0.156
# item: ('bagels', 'soda') , 0.157
# item: ('toilet paper', 'beef') , 0.157
# item: ('ice cream', 'sugar') , 0.157
# item: ('pasta', 'aluminum foil') , 0.157
# item: ('ketchup', 'laundry detergent') , 0.157
# item: ('poultry', 'flour') , 0.157
# item: ('aluminum foil', 'eggs') , 0.157
# item: ('lunch meat', 'laundry detergent') , 0.157
# item: ('aluminum foil', 'all- purpose') , 0.157
# item: ('juice', 'soda') , 0.157
# item: ('shampoo', 'toilet paper') , 0.157
# item: ('aluminum foil', 'soap') , 0.157
# item: ('dinner rolls', 'juice') , 0.157
# item: ('ice cream', 'all- purpose') , 0.157
# item: ('dishwashing liquid/detergent', 'beef') , 0.157
# item: ('waffles', 'beef') , 0.157
# item: ('vegetables', 'yogurt', 'eggs') , 0.157
# item: ('lunch meat', 'vegetables', 'waffles') , 0.157
# item: ('ketchup', 'aluminum foil') , 0.158
# item: ('aluminum foil', 'fruits') , 0.158
# item: ('shampoo', 'cheeses') , 0.158
# item: ('paper towels', 'mixes') , 0.158
# item: ('ketchup', 'bagels') , 0.158
# item: ('beef', 'spaghetti sauce') , 0.158
# item: ('ice cream', 'sandwich loaves') , 0.158
# item: ('individual meals', 'spaghetti sauce') , 0.158
# item: ('ketchup', 'soda') , 0.158
# item: ('dinner rolls', 'tortillas') , 0.158
# item: ('lunch meat', 'beef') , 0.158
# item: ('lunch meat', 'bagels') , 0.158
# item: ('shampoo', 'yogurt') , 0.158
# item: ('flour', 'soda') , 0.158
# item: ('sandwich loaves', 'soap') , 0.158
# item: ('shampoo', 'bagels') , 0.158
# item: ('dishwashing liquid/detergent', 'yogurt') , 0.158
# item: ('laundry detergent', 'butter') , 0.158
# item: ('milk', 'spaghetti sauce') , 0.158
# item: ('sandwich bags', 'cereals') , 0.158
# item: ('individual meals', 'yogurt') , 0.158
# item: ('ketchup', 'dinner rolls') , 0.158
# item: ('laundry detergent', 'yogurt') , 0.158
# item: ('fruits', 'yogurt') , 0.158
# item: ('mixes', 'spaghetti sauce') , 0.158
# item: ('sandwich bags', 'milk') , 0.158
# item: ('vegetables', 'soda', 'eggs') , 0.158
# item: ('lunch meat', 'vegetables', 'poultry') , 0.158
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.159
# item: ('shampoo', 'aluminum foil') , 0.159
# item: ('sugar', 'yogurt') , 0.159
# item: ('poultry', 'paper towels') , 0.159
# item: ('coffee/tea', 'soap') , 0.159
# item: ('cereals', 'tortillas') , 0.159
# item: ('milk', 'mixes') , 0.159
# item: ('sandwich bags', 'waffles') , 0.159
# item: ('shampoo', 'cereals') , 0.159
# item: ('juice', 'paper towels') , 0.159
# item: ('eggs', 'mixes') , 0.159
# item: ('coffee/tea', 'soda') , 0.159
# item: ('tortillas', 'eggs') , 0.159
# item: ('pasta', 'yogurt') , 0.159
# item: ('ice cream', 'spaghetti sauce') , 0.159
# item: ('lunch meat', 'eggs') , 0.159
# item: ('coffee/tea', 'eggs') , 0.159
# item: ('butter', 'eggs') , 0.159
# item: ('individual meals', 'dishwashing liquid/detergent') , 0.159
# item: ('dishwashing liquid/detergent', 'paper towels') , 0.159
# item: ('laundry detergent', 'ice cream') , 0.159
# item: ('coffee/tea', 'aluminum foil') , 0.159
# item: ('dinner rolls', 'coffee/tea') , 0.159
# item: ('sandwich bags', 'soap') , 0.159
# item: ('pasta', 'spaghetti sauce') , 0.160
# item: ('bagels', 'waffles') , 0.160
# item: ('sandwich loaves', 'individual meals') , 0.160
# item: ('cheeses', 'beef') , 0.160
# item: ('soap', 'individual meals') , 0.160
# item: ('shampoo', 'lunch meat') , 0.160
# item: ('pasta', 'soap') , 0.160

# %%
print ('# # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #') 
print ('Case 2 (minimum support=0.20 and minimum confidence=83)') 
print ('Case 2 Reasoning:')
print ('Case 2 Output:') 
! python apriori.py -f DATASET.csv -s 0.20 -c 0.83
# Out:
# item: ('yogurt', 'spaghetti sauce') , 0.160
# item: ('lunch meat', 'all- purpose') , 0.160
# item: ('lunch meat', 'soda') , 0.160
# item: ('waffles', 'sugar') , 0.160
# item: ('cheeses', 'pasta') , 0.160
# item: ('aluminum foil', 'beef') , 0.160
# item: ('aluminum foil', 'paper towels') , 0.160
# item: ('ice cream', 'toilet paper') , 0.160
# item: ('aluminum foil', 'toilet paper') , 0.160
# item: ('all- purpose', 'eggs') , 0.160
# item: ('soap', 'beef') , 0.160
# item: ('flour', 'cheeses') , 0.160
# item: ('laundry detergent', 'mixes') , 0.160
# item: ('lunch meat', 'butter') , 0.160
# item: ('pasta', 'all- purpose') , 0.160
# item: ('cheeses', 'butter') , 0.160
# item: ('cereals', 'individual meals') , 0.160
# item: ('soap', 'dishwashing liquid/detergent') , 0.160
# item: ('ice cream', 'bagels') , 0.160
# item: ('poultry', 'vegetables', 'dishwashing liquid/detergent') , 0.160
# item: ('soap', 'spaghetti sauce') , 0.161
# item: ('beef', 'yogurt') , 0.161
# item: ('lunch meat', 'milk') , 0.161
# item: ('ketchup', 'juice') , 0.161
# item: ('lunch meat', 'cheeses') , 0.161
# item: ('beef', 'milk') , 0.161
# item: ('cereals', 'waffles') , 0.161
# item: ('dishwashing liquid/detergent', 'all- purpose') , 0.161
# item: ('cheeses', 'individual meals') , 0.161
# item: ('sandwich bags', 'tortillas') , 0.161
# item: ('ketchup', 'cheeses') , 0.161
# item: ('laundry detergent', 'cheeses') , 0.161
# item: ('aluminum foil', 'milk') , 0.161
# item: ('lunch meat', 'yogurt') , 0.161
# item: ('paper towels', 'soda') , 0.161
# item: ('laundry detergent', 'aluminum foil') , 0.161
# item: ('coffee/tea', 'yogurt') , 0.161
# item: ('lunch meat', 'aluminum foil') , 0.161
# item: ('aluminum foil', 'soda') , 0.162
# item: ('lunch meat', 'sugar') , 0.162
# item: ('ice cream', 'dinner rolls') , 0.162
# item: ('cereals', 'fruits') , 0.162
# item: ('ketchup', 'waffles') , 0.162
# item: ('pasta', 'waffles') , 0.162
# item: ('laundry detergent', 'spaghetti sauce') , 0.162
# item: ('bagels', 'milk') , 0.162
# item: ('pasta', 'dishwashing liquid/detergent') , 0.162
# item: ('lunch meat', 'juice') , 0.162
# item: ('paper towels', 'milk') , 0.162
# item: ('ice cream', 'beef') , 0.162
# item: ('toilet paper', 'paper towels') , 0.162
# item: ('poultry', 'pasta') , 0.162
# item: ('pasta', 'cereals') , 0.162
# item: ('soap', 'milk') , 0.162
# item: ('poultry', 'dinner rolls', 'vegetables') , 0.162
# item: ('lunch meat', 'dinner rolls') , 0.162
# item: ('cereals', 'soap') , 0.162
# item: ('bagels', 'juice') , 0.162
# item: ('ice cream', 'individual meals') , 0.162
# item: ('toilet paper', 'soda') , 0.162
# item: ('bagels', 'tortillas') , 0.162
# item: ('toilet paper', 'yogurt') , 0.162
# item: ('sugar', 'soda') , 0.162
# item: ('sandwich bags', 'soda') , 0.162
# item: ('tortillas', 'mixes') , 0.162
# item: ('bagels', 'cereals') , 0.162
# item: ('laundry detergent', 'all- purpose') , 0.162
# item: ('bagels', 'yogurt') , 0.162
# item: ('cheeses', 'soap') , 0.162
# item: ('dinner rolls', 'mixes') , 0.162
# item: ('aluminum foil', 'individual meals') , 0.162
# item: ('lunch meat', 'tortillas') , 0.163
# item: ('beef', 'eggs') , 0.163
# item: ('lunch meat', 'fruits') , 0.163
# item: ('cheeses', 'fruits') , 0.163
# item: ('sandwich bags', 'laundry detergent') , 0.163
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.163
# item: ('cheeses', 'mixes') , 0.163
# item: ('laundry detergent', 'soda') , 0.163
# item: ('laundry detergent', 'eggs') , 0.163
# item: ('cheeses', 'dishwashing liquid/detergent') , 0.163
# item: ('poultry', 'sandwich loaves') , 0.163
# item: ('eggs', 'spaghetti sauce') , 0.163
# item: ('toilet paper', 'eggs') , 0.163
# item: ('toilet paper', 'milk') , 0.163
# item: ('bagels', 'toilet paper') , 0.163
# item: ('soap', 'all- purpose') , 0.163
# item: ('waffles', 'fruits') , 0.163
# item: ('toilet paper', 'soap') , 0.164
# item: ('pork', 'poultry') , 0.164
# item: ('sandwich bags', 'ketchup') , 0.164
# item: ('bagels', 'mixes') , 0.164
# item: ('cereals', 'paper towels') , 0.164
# item: ('ketchup', 'soap') , 0.164
# item: ('waffles', 'spaghetti sauce') , 0.164
# item: ('lunch meat', 'toilet paper') , 0.164
# item: ('ketchup', 'coffee/tea') , 0.164
# item: ('yogurt', 'mixes') , 0.164
# item: ('dinner rolls', 'sugar') , 0.164
# item: ('pasta', 'paper towels') , 0.164
# item: ('lunch meat', 'paper towels') , 0.165
# item: ('ice cream', 'milk') , 0.165
# item: ('poultry', 'ketchup') , 0.165
# item: ('cheeses', 'spaghetti sauce') , 0.165
# item: ('ketchup', 'mixes') , 0.165
# item: ('laundry detergent', 'dinner rolls') , 0.165
# item: ('ice cream', 'dishwashing liquid/detergent') , 0.165
# item: ('juice', 'eggs') , 0.165
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.165
# item: ('ice cream', 'fruits') , 0.165
# item: ('ice cream', 'coffee/tea') , 0.165
# item: ('bagels', 'individual meals') , 0.165
# item: ('ketchup', 'eggs') , 0.166
# item: ('lunch meat', 'soap') , 0.166
# item: ('dinner rolls', 'aluminum foil') , 0.166
# item: ('laundry detergent', 'milk') , 0.166
# item: ('individual meals', 'soda') , 0.166
# item: ('fruits', 'beef') , 0.166
# item: ('ice cream', 'cereals') , 0.166
# item: ('poultry', 'butter') , 0.166
# item: ('paper towels', 'eggs') , 0.166
# item: ('aluminum foil', 'cereals') , 0.166
# item: ('dinner rolls', 'yogurt') , 0.166
# item: ('toilet paper', 'cereals') , 0.166
# item: ('all- purpose', 'yogurt') , 0.167
# item: ('ice cream', 'eggs') , 0.167
# item: ('ice cream', 'juice') , 0.167
# item: ('lunch meat', 'coffee/tea') , 0.167
# item: ('ice cream', 'soap') , 0.167
# item: ('soap', 'eggs') , 0.167
# item: ('soda', 'yogurt') , 0.167
# item: ('waffles', 'juice') , 0.167
# item: ('poultry', 'waffles') , 0.167
# item: ('dishwashing liquid/detergent', 'soda') , 0.167
# item: ('bagels', 'spaghetti sauce') , 0.167
# item: ('cereals', 'spaghetti sauce') , 0.167
# item: ('dinner rolls', 'cheeses') , 0.168
# item: ('poultry', 'fruits') , 0.168
# item: ('bagels', 'eggs') , 0.168
# item: ('soda', 'spaghetti sauce') , 0.168
# item: ('bagels', 'fruits') , 0.168
# item: ('yogurt', 'milk') , 0.168
# item: ('bagels', 'dishwashing liquid/detergent') , 0.168
# item: ('cheeses', 'toilet paper') , 0.168
# item: ('cheeses', 'coffee/tea') , 0.168
# item: ('ice cream', 'pasta') , 0.168
# item: ('waffles', 'all- purpose') , 0.168
# item: ('poultry', 'bagels') , 0.168
# item: ('cheeses', 'bagels') , 0.168
# item: ('dishwashing liquid/detergent', 'fruits') , 0.168
# item: ('milk', 'eggs') , 0.169
# item: ('bagels', 'aluminum foil') , 0.169
# item: ('cereals', 'beef') , 0.169
# item: ('cheeses', 'soda') , 0.169
# item: ('ice cream', 'soda') , 0.169
# item: ('lunch meat', 'spaghetti sauce') , 0.169
# item: ('lunch meat', 'cereals') , 0.169
# item: ('cheeses', 'aluminum foil') , 0.169
# item: ('shampoo', 'dinner rolls') , 0.169
# item: ('cereals', 'dishwashing liquid/detergent') , 0.169
# item: ('laundry detergent', 'cereals') , 0.169
# item: ('coffee/tea', 'cereals') , 0.169
# item: ('dinner rolls', 'waffles') , 0.169
# item: ('sandwich bags', 'cheeses') , 0.169
# item: ('waffles', 'eggs') , 0.169
# item: ('pasta', 'soda') , 0.169
# item: ('aluminum foil', 'waffles') , 0.169
# item: ('cheeses', 'eggs') , 0.169
# item: ('pasta', 'eggs') , 0.169
# item: ('poultry', 'individual meals') , 0.170
# item: ('ice cream', 'paper towels') , 0.170
# item: ('shampoo', 'juice') , 0.170
# item: ('poultry', 'beef') , 0.170
# item: ('dishwashing liquid/detergent', 'milk') , 0.170
# item: ('dinner rolls', 'cereals') , 0.171
# item: ('shampoo', 'poultry') , 0.171
# item: ('poultry', 'tortillas') , 0.171
# item: ('dinner rolls', 'soda') , 0.171
# item: ('poultry', 'spaghetti sauce') , 0.171
# item: ('poultry', 'toilet paper') , 0.171
# item: ('dishwashing liquid/detergent', 'eggs') , 0.171
# item: ('dinner rolls', 'spaghetti sauce') , 0.172
# item: ('aluminum foil', 'mixes') , 0.172
# item: ('aluminum foil', 'juice') , 0.172
# item: ('cereals', 'yogurt') , 0.172
# item: ('coffee/tea', 'waffles') , 0.172
# item: ('poultry', 'sandwich bags') , 0.172
# item: ('juice', 'spaghetti sauce') , 0.172
# item: ('cheeses', 'yogurt') , 0.172
# item: ('toilet paper', 'juice') , 0.172
# item: ('toilet paper', 'waffles') , 0.173
# item: ('dinner rolls', 'pasta') , 0.173
# item: ('cheeses', 'waffles') , 0.173
# item: ('waffles', 'soap') , 0.173
# item: ('soda', 'milk') , 0.173
# item: ('poultry', 'soda') , 0.173
# item: ('ice cream', 'waffles') , 0.173
# item: ('waffles', 'yogurt') , 0.174
# item: ('lunch meat', 'dishwashing liquid/detergent') , 0.174
# item: ('cereals', 'mixes') , 0.174
# item: ('cereals', 'milk') , 0.174
# item: ('dinner rolls', 'eggs') , 0.174
# item: ('lunch meat', 'ice cream') , 0.174
# item: ('cereals', 'eggs') , 0.175
# item: ('yogurt', 'eggs') , 0.175
# item: ('soap', 'soda') , 0.175
# item: ('poultry', 'coffee/tea') , 0.175
# item: ('poultry', 'laundry detergent') , 0.175
# item: ('cheeses', 'cereals') , 0.175
# item: ('poultry', 'all- purpose') , 0.176
# item: ('poultry', 'aluminum foil') , 0.176
# item: ('waffles', 'dishwashing liquid/detergent') , 0.176
# # # # # # # # # #  Code for Task 2, Case:2 # # # # # # # # #item: ('ice cream', 'aluminum foil') , 0.176
# Case 2 (minimum support=0.20 and minimum confidence=83)
# Case 2 Reasoning:
# Case 2 Output:
#
# item: ('juice', 'yogurt') , 0.176
# item: ('poultry', 'juice') , 0.176
# item: ('poultry', 'eggs') , 0.176
# item: ('aluminum foil', 'yogurt') , 0.176
# item: ('lunch meat', 'individual meals') , 0.177
# item: ('waffles', 'soda') , 0.177
# item: ('poultry', 'milk') , 0.178
# item: ('poultry', 'sugar') , 0.179
# item: ('poultry', 'ice cream') , 0.179
# item: ('ice cream', 'cheeses') , 0.179
# item: ('dishwashing liquid/detergent', 'mixes') , 0.180
# item: ('poultry', 'cheeses') , 0.181
# item: ('poultry', 'cereals') , 0.181
# item: ('poultry', 'yogurt') , 0.181
# item: ('poultry', 'mixes') , 0.182
# item: ('poultry', 'soap') , 0.183
# item: ('lunch meat', 'waffles') , 0.184
# item: ('lunch meat', 'poultry') , 0.186
# item: ('poultry', 'dishwashing liquid/detergent') , 0.187
# item: ('soda', 'eggs') , 0.187
# item: ('poultry', 'dinner rolls') , 0.195
# item: ('pork', 'vegetables') , 0.270
# item: ('hand soap', 'vegetables') , 0.270
# item: ('flour', 'vegetables') , 0.277
# item: ('sandwich loaves', 'vegetables') , 0.283
# item: ('vegetables', 'butter') , 0.284
# item: ('vegetables', 'tortillas') , 0.284
# item: ('vegetables', 'individual meals') , 0.285
# item: ('pasta', 'vegetables') , 0.286
# item: ('shampoo', 'vegetables') , 0.288
# item: ('vegetables', 'toilet paper') , 0.290
# item: ('vegetables', 'paper towels') , 0.290
# item: ('vegetables', 'all- purpose') , 0.290
# item: ('coffee/tea', 'vegetables') , 0.290
# item: ('vegetables', 'fruits') , 0.291
# item: ('vegetables', 'beef') , 0.291
# item: ('ketchup', 'vegetables') , 0.291
# item: ('sandwich bags', 'vegetables') , 0.293
# item: ('vegetables', 'juice') , 0.294
# item: ('vegetables', 'soap') , 0.295
# item: ('vegetables', 'mixes') , 0.296
# item: ('vegetables', 'milk') , 0.296
# item: ('vegetables', 'spaghetti sauce') , 0.297
# item: ('vegetables', 'sugar') , 0.298
# item: ('bagels', 'vegetables') , 0.300
# item: ('ice cream', 'vegetables') , 0.303
# item: ('vegetables', 'soda') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('dinner rolls', 'vegetables') , 0.308
# item: ('cheeses', 'vegetables') , 0.309
# item: ('laundry detergent', 'vegetables') , 0.309
# item: ('vegetables', 'aluminum foil') , 0.311
# item: ('vegetables', 'cereals') , 0.311
# item: ('lunch meat', 'vegetables') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('vegetables', 'yogurt') , 0.319
# item: ('vegetables', 'eggs') , 0.327
# item: ('poultry', 'vegetables') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('sandwich bags',) , 0.368
# item: ('butter',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('pasta',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('mixes',) , 0.376
# item: ('individual meals',) , 0.376
# item: ('juice',) , 0.377
# item: ('laundry detergent',) , 0.378
# item: ('toilet paper',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.384
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('soda',) , 0.391
# item: ('cheeses',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('individual meals',) ==> ('vegetables',) , 0.759
# Rule: ('ice cream',) ==> ('vegetables',) , 0.760
# Rule: ('pork',) ==> ('vegetables',) , 0.760
# Rule: ('coffee/tea',) ==> ('vegetables',) , 0.764
# Rule: ('toilet paper',) ==> ('vegetables',) , 0.766
# Rule: ('tortillas',) ==> ('vegetables',) , 0.767
# Rule: ('pasta',) ==> ('vegetables',) , 0.771
# Rule: ('butter',) ==> ('vegetables',) , 0.771
# Rule: ('all- purpose',) ==> ('vegetables',) , 0.773
# Rule: ('beef',) ==> ('vegetables',) , 0.778
# Rule: ('soap',) ==> ('vegetables',) , 0.778
# Rule: ('milk',) ==> ('vegetables',) , 0.778
# Rule: ('bagels',) ==> ('vegetables',) , 0.779
# Rule: ('juice',) ==> ('vegetables',) , 0.781
# Rule: ('shampoo',) ==> ('vegetables',) , 0.781
# Rule: ('hand soap',) ==> ('vegetables',) , 0.782
# Rule: ('soda',) ==> ('vegetables',) , 0.782
# Rule: ('flour',) ==> ('vegetables',) , 0.784
# Rule: ('fruits',) ==> ('vegetables',) , 0.784
# Rule: ('ketchup',) ==> ('vegetables',) , 0.785
# Rule: ('cereals',) ==> ('vegetables',) , 0.785
# Rule: ('mixes',) ==> ('vegetables',) , 0.787
# Rule: ('poultry',) ==> ('vegetables',) , 0.787
# Rule: ('lunch meat',) ==> ('vegetables',) , 0.789
# Rule: ('dishwashing liquid/detergent',) ==> ('vegetables',) , 0.790
# Rule: ('cheeses',) ==> ('vegetables',) , 0.791
# Rule: ('dinner rolls',) ==> ('vegetables',) , 0.792
# Rule: ('spaghetti sauce',) ==> ('vegetables',) , 0.795
# Rule: ('sandwich bags',) ==> ('vegetables',) , 0.797
# Rule: ('paper towels',) ==> ('vegetables',) , 0.799
# Rule: ('waffles',) ==> ('vegetables',) , 0.800
# Rule: ('aluminum foil',) ==> ('vegetables',) , 0.808
# Rule: ('sandwich loaves',) ==> ('vegetables',) , 0.809
# Rule: ('laundry detergent',) ==> ('vegetables',) , 0.817
# Rule: ('sugar',) ==> ('vegetables',) , 0.825
# Rule: ('poultry', 'dinner rolls') ==> ('vegetables',) , 0.829
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838
# Rule: ('poultry', 'yogurt') ==> ('vegetables',) , 0.845
# Rule: ('soda', 'eggs') ==> ('vegetables',) , 0.845
# Rule: ('poultry', 'sugar') ==> ('vegetables',) , 0.848
# Rule: ('lunch meat', 'poultry') ==> ('vegetables',) , 0.849
# Rule: ('lunch meat', 'waffles') ==> ('vegetables',) , 0.852
# Rule: ('poultry', 'dishwashing liquid/detergent') ==> ('vegetables',) , 0.854
# Rule: ('poultry', 'mixes') ==> ('vegetables',) , 0.860
# Rule: ('aluminum foil', 'yogurt') ==> ('vegetables',) , 0.861
# Rule: ('cereals', 'eggs') ==> ('vegetables',) , 0.864
# Rule: ('poultry', 'eggs') ==> ('vegetables',) , 0.881
# Rule: ('cheeses', 'eggs') ==> ('vegetables',) , 0.886
# Rule: ('laundry detergent', 'cereals') ==> ('vegetables',) , 0.891
# Rule: ('dishwashing liquid/detergent', 'eggs') ==> ('vegetables',) , 0.897
# Rule: ('dinner rolls', 'eggs') ==> ('vegetables',) , 0.899
# Rule: ('yogurt', 'eggs') ==> ('vegetables',) , 0.899
#
#
#
# ------------ITEMS-----------------
# item: ('pork', 'vegetables') , 0.270
# item: ('hand soap', 'vegetables') , 0.270
# item: ('flour', 'vegetables') , 0.277
# item: ('sandwich loaves', 'vegetables') , 0.283
# item: ('tortillas', 'vegetables') , 0.284
# item: ('butter', 'vegetables') , 0.284
# item: ('individual meals', 'vegetables') , 0.285
# item: ('pasta', 'vegetables') , 0.286
# item: ('shampoo', 'vegetables') , 0.288
# item: ('paper towels', 'vegetables') , 0.290
# item: ('toilet paper', 'vegetables') , 0.290
# item: ('coffee/tea', 'vegetables') , 0.290
# item: ('all- purpose', 'vegetables') , 0.290
# item: ('fruits', 'vegetables') , 0.291
# item: ('ketchup', 'vegetables') , 0.291
# item: ('beef', 'vegetables') , 0.291
# item: ('sandwich bags', 'vegetables') , 0.293
# item: ('juice', 'vegetables') , 0.294
# item: ('soap', 'vegetables') , 0.295
# item: ('vegetables', 'mixes') , 0.296
# item: ('milk', 'vegetables') , 0.296
# item: ('spaghetti sauce', 'vegetables') , 0.297
# item: ('sugar', 'vegetables') , 0.298
# item: ('bagels', 'vegetables') , 0.300
# item: ('ice cream', 'vegetables') , 0.303
# item: ('vegetables', 'soda') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('vegetables', 'dinner rolls') , 0.308
# item: ('cheeses', 'vegetables') , 0.309
# item: ('laundry detergent', 'vegetables') , 0.309
# item: ('aluminum foil', 'vegetables') , 0.311
# item: ('cereals', 'vegetables') , 0.311
# item: ('lunch meat', 'vegetables') , 0.312
# item: ('waffles', 'vegetables') , 0.315
# item: ('yogurt', 'vegetables') , 0.319
# item: ('eggs', 'vegetables') , 0.327
# item: ('poultry', 'vegetables') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('butter',) , 0.368
# item: ('sandwich bags',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('pasta',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('all- purpose',) , 0.375
# item: ('beef',) , 0.375
# item: ('mixes',) , 0.376
# item: ('individual meals',) , 0.376
# item: ('juice',) , 0.377
# item: ('toilet paper',) , 0.378
# item: ('laundry detergent',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.384
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('soda',) , 0.391
# item: ('cheeses',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('yogurt',) ==> ('vegetables',) , 0.831
# Rule: ('eggs',) ==> ('vegetables',) , 0.838

# %%
print ('# # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #') 
print ('Case 3 (minimum support=XX and minimum confidence=YY)')
print ('Case 3 Reasoning:')
print ('Case 3 Output:')
! python apriori.py -f DATASET.csv -s 0.12 -c 0.9
# Out:
# # # # # # # # # #  Code for Task 2, Case:3 # # # # # # # # #
# Case 3 (minimum support=XX and minimum confidence=YY)
# Case 3 Reasoning:
# Case 3 Output:
#
# ------------ITEMS-----------------
# item: ('juice', 'vegetables', 'pork') , 0.120
# item: ('juice', 'vegetables', 'mixes') , 0.120
# item: ('vegetables', 'cheeses', 'all- purpose') , 0.120
# item: ('vegetables', 'pork', 'waffles') , 0.120
# item: ('vegetables', 'lunch meat', 'ketchup') , 0.120
# item: ('pasta', 'vegetables', 'individual meals') , 0.120
# item: ('vegetables', 'pork', 'spaghetti sauce') , 0.120
# item: ('vegetables', 'pork', 'all- purpose') , 0.120
# item: ('mixes', 'vegetables', 'all- purpose') , 0.120
# item: ('vegetables', 'fruits', 'all- purpose') , 0.120
# item: ('vegetables', 'soda', 'mixes') , 0.120
# item: ('juice', 'vegetables', 'individual meals') , 0.120
# item: ('vegetables', 'flour', 'cereals') , 0.120
# item: ('vegetables', 'fruits', 'ketchup') , 0.120
# item: ('vegetables', 'coffee/tea', 'individual meals') , 0.120
# item: ('vegetables', 'individual meals', 'toilet paper') , 0.120
# item: ('vegetables', 'fruits', 'sandwich loaves') , 0.120
# item: ('paper towels', 'vegetables', 'sugar') , 0.120
# item: ('vegetables', 'coffee/tea', 'sandwich bags') , 0.120
# item: ('vegetables', 'sandwich loaves', 'flour') , 0.120
# item: ('vegetables', 'coffee/tea', 'bagels') , 0.120
# item: ('juice', 'vegetables', 'sandwich loaves') , 0.120
# item: ('vegetables', 'coffee/tea', 'toilet paper') , 0.121
# item: ('vegetables', 'spaghetti sauce', 'all- purpose') , 0.121
# item: ('vegetables', 'shampoo', 'dishwashing liquid/detergent') , 0.121
# item: ('vegetables', 'soap', 'bagels') , 0.121
# item: ('vegetables', 'tortillas', 'waffles') , 0.121
# item: ('pasta', 'vegetables', 'shampoo') , 0.121
# item: ('vegetables', 'sugar', 'sandwich loaves') , 0.121
# item: ('vegetables', 'bagels', 'butter') , 0.121
# item: ('pasta', 'vegetables', 'flour') , 0.121
# item: ('vegetables', 'toilet paper', 'spaghetti sauce') , 0.121
# item: ('vegetables', 'pork', 'ketchup') , 0.121
# item: ('vegetables', 'hand soap', 'mixes') , 0.121
# item: ('vegetables', 'eggs', 'sandwich loaves') , 0.121
# item: ('vegetables', 'soda', 'sandwich loaves') , 0.121
# item: ('vegetables', 'lunch meat', 'hand soap') , 0.121
# item: ('vegetables', 'sandwich loaves', 'cereals') , 0.121
# item: ('vegetables', 'dishwashing liquid/detergent', 'flour') , 0.121
# item: ('pasta', 'vegetables', 'ketchup') , 0.121
# item: ('vegetables', 'spaghetti sauce', 'dishwashing liquid/detergent') , 0.122
# item: ('vegetables', 'bagels', 'all- purpose') , 0.122
# item: ('paper towels', 'vegetables', 'sandwich loaves') , 0.122
# item: ('vegetables', 'milk', 'shampoo') , 0.122
# item: ('vegetables', 'coffee/tea', 'flour') , 0.122
# item: ('vegetables', 'butter', 'cereals') , 0.122
# item: ('pasta', 'vegetables', 'milk') , 0.122
# item: ('vegetables', 'coffee/tea', 'milk') , 0.122
# item: ('vegetables', 'hand soap', 'poultry') , 0.122
# item: ('vegetables', 'soap', 'flour') , 0.122
# item: ('juice', 'vegetables', 'cheeses') , 0.122
# item: ('juice', 'vegetables', 'all- purpose') , 0.122
# item: ('vegetables', 'individual meals', 'dinner rolls') , 0.122
# item: ('vegetables', 'sugar', 'milk') , 0.122
# item: ('vegetables', 'individual meals', 'beef') , 0.122
# item: ('vegetables', 'sugar', 'shampoo') , 0.122
# item: ('vegetables', 'coffee/tea', 'dishwashing liquid/detergent') , 0.122
# item: ('vegetables', 'shampoo', 'ice cream') , 0.122
# item: ('paper towels', 'vegetables', 'individual meals') , 0.122
# item: ('vegetables', 'eggs', 'hand soap') , 0.122
# item: ('vegetables', 'butter', 'ice cream') , 0.122
# item: ('vegetables', 'soda', 'all- purpose') , 0.123
# item: ('vegetables', 'fruits', 'soap') , 0.123
# item: ('vegetables', 'toilet paper', 'all- purpose') , 0.123
# item: ('vegetables', 'spaghetti sauce', 'sandwich loaves') , 0.123
# item: ('vegetables', 'butter', 'soda') , 0.123
# item: ('paper towels', 'vegetables', 'fruits') , 0.123
# item: ('vegetables', 'butter', 'waffles') , 0.123
# item: ('vegetables', 'beef', 'sandwich bags') , 0.123
# item: ('vegetables', 'pork', 'mixes') , 0.123
# item: ('vegetables', 'bagels', 'pork') , 0.123
# item: ('pasta', 'vegetables', 'juice') , 0.123
# item: ('vegetables', 'soap', 'mixes') , 0.123
# item: ('vegetables', 'tortillas', 'sandwich bags') , 0.123
# item: ('vegetables', 'shampoo', 'sandwich bags') , 0.123
# item: ('vegetables', 'cereals', 'all- purpose') , 0.123
# item: ('vegetables', 'toilet paper', 'shampoo') , 0.123
# item: ('vegetables', 'individual meals', 'tortillas') , 0.123
# item: ('vegetables', 'individual meals', 'shampoo') , 0.123
# item: ('pasta', 'vegetables', 'hand soap') , 0.123
# item: ('vegetables', 'sugar', 'individual meals') , 0.123
# item: ('vegetables', 'milk', 'all- purpose') , 0.123
# item: ('vegetables', 'butter', 'spaghetti sauce') , 0.123
# item: ('vegetables', 'ketchup', 'cereals') , 0.124
# item: ('vegetables', 'coffee/tea', 'shampoo') , 0.124
# item: ('vegetables', 'milk', 'cheeses') , 0.124
# item: ('vegetables', 'ketchup', 'all- purpose') , 0.124
# item: ('juice', 'soda', 'vegetables') , 0.124
# item: ('vegetables', 'individual meals', 'sandwich bags') , 0.124
# item: ('vegetables', 'spaghetti sauce', 'sandwich bags') , 0.124
# item: ('pasta', 'vegetables', 'coffee/tea') , 0.124
# item: ('vegetables', 'tortillas', 'mixes') , 0.124
# item: ('vegetables', 'fruits', 'sandwich bags') , 0.124
# item: ('pasta', 'bagels', 'vegetables') , 0.124
# item: ('vegetables', 'laundry detergent', 'flour') , 0.124
# item: ('vegetables', 'tortillas', 'sugar') , 0.124
# item: ('vegetables', 'lunch meat', 'mixes') , 0.124
# item: ('pasta', 'vegetables', 'sugar') , 0.124
# item: ('vegetables', 'bagels', 'shampoo') , 0.124
# item: ('vegetables', 'sugar', 'flour') , 0.125
# item: ('vegetables', 'butter', 'cheeses') , 0.125
# item: ('vegetables', 'tortillas', 'toilet paper') , 0.125
# item: ('vegetables', 'pork', 'dishwashing liquid/detergent') , 0.125
# item: ('vegetables', 'shampoo', 'beef') , 0.125
# item: ('vegetables', 'toilet paper', 'ice cream') , 0.125
# item: ('vegetables', 'spaghetti sauce', 'ketchup') , 0.125
# item: ('vegetables', 'pork', 'lunch meat') , 0.125
# item: ('vegetables', 'dinner rolls', 'butter') , 0.125
# item: ('soap', 'vegetables', 'shampoo') , 0.125
# item: ('vegetables', 'laundry detergent', 'sugar') , 0.125
# item: ('vegetables', 'eggs', 'flour') , 0.125
# item: ('vegetables', 'ketchup', 'flour') , 0.125
# item: ('vegetables', 'toilet paper', 'beef') , 0.125
# item: ('vegetables', 'lunch meat', 'sandwich loaves') , 0.125
# item: ('vegetables', 'butter', 'lunch meat') , 0.125
# item: ('vegetables', 'waffles', 'sandwich loaves') , 0.125
# item: ('aluminum foil', 'vegetables', 'butter') , 0.125
# item: ('juice', 'vegetables', 'cereals') , 0.125
# item: ('vegetables', 'sugar', 'spaghetti sauce') , 0.125
# item: ('vegetables', 'sugar', 'bagels') , 0.126
# item: ('vegetables', 'soda', 'cereals') , 0.126
# item: ('juice', 'vegetables', 'milk') , 0.126
# item: ('vegetables', 'tortillas', 'dishwashing liquid/detergent') , 0.126
# item: ('vegetables', 'butter', 'mixes') , 0.126
# item: ('vegetables', 'pork', 'yogurt') , 0.126
# item: ('vegetables', 'tortillas', 'cereals') , 0.126
# item: ('vegetables', 'milk', 'sandwich bags') , 0.126
# item: ('aluminum foil', 'vegetables', 'sugar') , 0.126
# item: ('vegetables', 'bagels', 'tortillas') , 0.126
# item: ('pasta', 'vegetables', 'all- purpose') , 0.126
# item: ('vegetables', 'fruits', 'spaghetti sauce') , 0.126
# item: ('paper towels', 'sandwich bags', 'vegetables') , 0.126
# item: ('vegetables', 'soap', 'yogurt') , 0.126
# item: ('vegetables', 'sandwich loaves', 'mixes') , 0.126
# item: ('vegetables', 'soda', 'toilet paper') , 0.126
# item: ('vegetables', 'coffee/tea', 'soda') , 0.126
# item: ('mixes', 'vegetables', 'flour') , 0.126
# item: ('paper towels', 'vegetables', 'beef') , 0.126
# item: ('vegetables', 'bagels', 'beef') , 0.126
# item: ('juice', 'vegetables', 'butter') , 0.126
# item: ('vegetables', 'individual meals', 'dishwashing liquid/detergent') , 0.126
# item: ('vegetables', 'toilet paper', 'mixes') , 0.126
# item: ('paper towels', 'vegetables', 'cheeses') , 0.126
# item: ('vegetables', 'sandwich bags', 'mixes') , 0.126
# item: ('vegetables', 'individual meals', 'cereals') , 0.126
# item: ('vegetables', 'dinner rolls', 'all- purpose') , 0.126
# item: ('vegetables', 'coffee/tea', 'ice cream') , 0.126
# item: ('vegetables', 'ketchup', 'ice cream') , 0.126
# item: ('vegetables', 'toilet paper', 'dishwashing liquid/detergent') , 0.126
# item: ('juice', 'vegetables', 'beef') , 0.126
# item: ('vegetables', 'soap', 'coffee/tea') , 0.126
# item: ('vegetables', 'laundry detergent', 'fruits') , 0.126
# item: ('vegetables', 'coffee/tea', 'dinner rolls') , 0.126
# item: ('aluminum foil', 'vegetables', 'individual meals') , 0.126
# item: ('vegetables', 'dishwashing liquid/detergent', 'sandwich bags') , 0.126
# item: ('vegetables', 'sandwich loaves', 'coffee/tea') , 0.126
# item: ('paper towels', 'vegetables', 'mixes') , 0.126
# item: ('aluminum foil', 'vegetables', 'soap') , 0.126
# item: ('vegetables', 'ketchup', 'dishwashing liquid/detergent') , 0.126
# item: ('vegetables', 'beef', 'soda') , 0.126
# item: ('vegetables', 'dinner rolls', 'hand soap') , 0.126
# item: ('paper towels', 'bagels', 'vegetables') , 0.126
# item: ('vegetables', 'shampoo', 'mixes') , 0.126
# item: ('vegetables', 'lunch meat', 'all- purpose') , 0.126
# item: ('vegetables', 'sugar', 'soap') , 0.127
# item: ('vegetables', 'bagels', 'sandwich bags') , 0.127
# item: ('vegetables', 'bagels', 'ketchup') , 0.127
# item: ('vegetables', 'sandwich bags', 'cereals') , 0.127
# item: ('vegetables', 'soda', 'ketchup') , 0.127
# item: ('vegetables', 'butter', 'sandwich bags') , 0.127
# item: ('vegetables', 'waffles', 'mixes') , 0.127
# item: ('vegetables', 'individual meals', 'spaghetti sauce') , 0.127
# item: ('vegetables', 'sugar', 'cheeses') , 0.127
# item: ('vegetables', 'tortillas', 'dinner rolls') , 0.127
# item: ('vegetables', 'coffee/tea', 'paper towels') , 0.127
# item: ('vegetables', 'milk', 'soap') , 0.127
# item: ('vegetables', 'milk', 'ketchup') , 0.127
# item: ('vegetables', 'laundry detergent', 'paper towels') , 0.127
# item: ('vegetables', 'milk', 'spaghetti sauce') , 0.127
# item: ('vegetables', 'beef', 'ketchup') , 0.127
# item: ('vegetables', 'lunch meat', 'flour') , 0.127
# item: ('aluminum foil', 'vegetables', 'sandwich bags') , 0.127
# item: ('paper towels', 'vegetables', 'shampoo') , 0.127
# item: ('vegetables', 'cheeses', 'flour') , 0.127
# item: ('vegetables', 'shampoo', 'waffles') , 0.127
# item: ('butter', 'beef') , 0.128
# item: ('fruits', 'pork') , 0.128
# item: ('vegetables', 'pork', 'poultry') , 0.128
# item: ('soap', 'vegetables', 'dinner rolls') , 0.128
# item: ('vegetables', 'spaghetti sauce', 'mixes') , 0.128
# item: ('juice', 'vegetables', 'dishwashing liquid/detergent') , 0.128
# item: ('vegetables', 'dishwashing liquid/detergent', 'all- purpose') , 0.128
# item: ('vegetables', 'dinner rolls', 'ketchup') , 0.128
# item: ('vegetables', 'toilet paper', 'lunch meat') , 0.128
# item: ('vegetables', 'milk', 'beef') , 0.128
# item: ('juice', 'vegetables', 'soap') , 0.128
# item: ('vegetables', 'eggs', 'pork') , 0.128
# item: ('vegetables', 'dinner rolls', 'sandwich bags') , 0.128
# item: ('vegetables', 'sugar', 'toilet paper') , 0.128
# item: ('vegetables', 'ice cream', 'all- purpose') , 0.128
# item: ('vegetables', 'cheeses', 'sandwich loaves') , 0.128
# item: ('vegetables', 'fruits', 'cereals') , 0.128
# item: ('vegetables', 'eggs', 'sandwich bags') , 0.128
# item: ('vegetables', 'laundry detergent', 'bagels') , 0.128
# item: ('paper towels', 'vegetables', 'spaghetti sauce') , 0.128
# item: ('aluminum foil', 'vegetables', 'sandwich loaves') , 0.128
# item: ('vegetables', 'spaghetti sauce', 'ice cream') , 0.128
# item: ('vegetables', 'shampoo', 'soda') , 0.128
# item: ('vegetables', 'beef', 'spaghetti sauce') , 0.128
# item: ('vegetables', 'milk', 'dinner rolls') , 0.128
# item: ('vegetables', 'milk', 'mixes') , 0.128
# item: ('vegetables', 'eggs', 'shampoo') , 0.128
# item: ('pasta', 'vegetables', 'dishwashing liquid/detergent') , 0.128
# item: ('vegetables', 'bagels', 'ice cream') , 0.128
# item: ('laundry detergent', 'sandwich loaves') , 0.129
# item: ('vegetables', 'soda', 'sandwich bags') , 0.129
# item: ('vegetables', 'sandwich bags', 'lunch meat') , 0.129
# item: ('vegetables', 'toilet paper', 'ketchup') , 0.129
# item: ('vegetables', 'poultry', 'flour') , 0.129
# item: ('vegetables', 'sandwich bags', 'ice cream') , 0.129
# item: ('vegetables', 'dinner rolls', 'flour') , 0.129
# item: ('aluminum foil', 'vegetables', 'flour') , 0.129
# item: ('vegetables', 'dinner rolls', 'toilet paper') , 0.129
# item: ('vegetables', 'soda', 'bagels') , 0.129
# item: ('vegetables', 'sandwich loaves', 'ketchup') , 0.129
# item: ('vegetables', 'dinner rolls', 'sandwich loaves') , 0.129
# item: ('pasta', 'vegetables', 'soap') , 0.129
# item: ('paper towels', 'vegetables', 'waffles') , 0.129
# item: ('vegetables', 'shampoo', 'sandwich loaves') , 0.129
# item: ('vegetables', 'beef', 'dishwashing liquid/detergent') , 0.129
# item: ('vegetables', 'individual meals', 'ice cream') , 0.129
# item: ('pork', 'hand soap') , 0.130
# item: ('vegetables', 'beef', 'cheeses') , 0.130
# item: ('juice', 'coffee/tea', 'vegetables') , 0.130
# item: ('aluminum foil', 'vegetables', 'spaghetti sauce') , 0.130
# item: ('vegetables', 'laundry detergent', 'pasta') , 0.130
# item: ('vegetables', 'individual meals', 'waffles') , 0.130
# item: ('aluminum foil', 'vegetables', 'ketchup') , 0.130
# item: ('vegetables', 'laundry detergent', 'lunch meat') , 0.130
# item: ('pasta', 'vegetables', 'waffles') , 0.130
# item: ('vegetables', 'soap', 'all- purpose') , 0.130
# item: ('aluminum foil', 'vegetables', 'fruits') , 0.130
# item: ('vegetables', 'milk', 'toilet paper') , 0.130
# item: ('vegetables', 'soap', 'dishwashing liquid/detergent') , 0.130
# item: ('vegetables', 'yogurt', 'ice cream') , 0.130
# item: ('vegetables', 'soda', 'flour') , 0.130
# item: ('vegetables', 'bagels', 'milk') , 0.130
# item: ('vegetables', 'soap', 'sandwich bags') , 0.130
# item: ('vegetables', 'waffles', 'beef') , 0.131
# item: ('vegetables', 'individual meals', 'laundry detergent') , 0.131
# item: ('vegetables', 'dinner rolls', 'ice cream') , 0.131
# item: ('soap', 'vegetables', 'toilet paper') , 0.131
# item: ('vegetables', 'yogurt', 'ketchup') , 0.131
# item: ('vegetables', 'bagels', 'cereals') , 0.131
# item: ('vegetables', 'individual meals', 'soap') , 0.131
# item: ('vegetables', 'soap', 'beef') , 0.131
# item: ('vegetables', 'tortillas', 'yogurt') , 0.131
# item: ('vegetables', 'laundry detergent', 'soap') , 0.131
# item: ('paper towels', 'vegetables', 'soap') , 0.131
# item: ('vegetables', 'cheeses', 'bagels') , 0.131
# item: ('vegetables', 'laundry detergent', 'toilet paper') , 0.131
# item: ('aluminum foil', 'vegetables', 'all- purpose') , 0.131
# item: ('aluminum foil', 'vegetables', 'coffee/tea') , 0.131
# item: ('vegetables', 'sugar', 'beef') , 0.131
# item: ('vegetables', 'toilet paper', 'yogurt') , 0.131
# item: ('vegetables', 'shampoo', 'yogurt') , 0.131
# item: ('vegetables', 'soap', 'cereals') , 0.131
# item: ('vegetables', 'fruits', 'waffles') , 0.131
# item: ('paper towels', 'vegetables', 'milk') , 0.131
# item: ('butter', 'hand soap') , 0.132
# item: ('bagels', 'hand soap') , 0.132
# item: ('sandwich loaves', 'dishwashing liquid/detergent') , 0.132
# item: ('pork', 'sandwich loaves') , 0.132
# item: ('sugar', 'pork') , 0.132
# item: ('sandwich bags', 'sugar') , 0.132
# item: ('paper towels', 'vegetables', 'dinner rolls') , 0.132
# item: ('vegetables', 'bagels', 'dinner rolls') , 0.132
# item: ('vegetables', 'cereals', 'ice cream') , 0.132
# item: ('pasta', 'vegetables', 'paper towels') , 0.132
# item: ('vegetables', 'yogurt', 'flour') , 0.132
# item: ('juice', 'vegetables', 'ice cream') , 0.132
# item: ('vegetables', 'sugar', 'cereals') , 0.132
# item: ('vegetables', 'sugar', 'eggs') , 0.132
# item: ('vegetables', 'toilet paper', 'cheeses') , 0.132
# item: ('vegetables', 'tortillas', 'lunch meat') , 0.132
# item: ('vegetables', 'fruits', 'poultry') , 0.132
# item: ('vegetables', 'milk', 'ice cream') , 0.132
# item: ('aluminum foil', 'vegetables', 'milk') , 0.132
# item: ('vegetables', 'bagels', 'mixes') , 0.132
# item: ('vegetables', 'individual meals', 'cheeses') , 0.132
# item: ('vegetables', 'fruits', 'yogurt') , 0.132
# item: ('aluminum foil', 'vegetables', 'toilet paper') , 0.132
# item: ('paper towels', 'vegetables', 'dishwashing liquid/detergent') , 0.132
# item: ('paper towels', 'vegetables', 'toilet paper') , 0.132
# item: ('vegetables', 'milk', 'lunch meat') , 0.132
# item: ('vegetables', 'lunch meat', 'beef') , 0.132
# item: ('spaghetti sauce', 'flour') , 0.133
# item: ('hand soap', 'flour') , 0.133
# item: ('paper towels', 'vegetables', 'all- purpose') , 0.133
# item: ('juice', 'vegetables', 'dinner rolls') , 0.133
# item: ('vegetables', 'fruits', 'beef') , 0.133
# item: ('vegetables', 'eggs', 'mixes') , 0.133
# item: ('vegetables', 'lunch meat', 'bagels') , 0.133
# item: ('pasta', 'vegetables', 'aluminum foil') , 0.133
# item: ('vegetables', 'cheeses', 'dishwashing liquid/detergent') , 0.133
# item: ('vegetables', 'shampoo', 'cheeses') , 0.133
# item: ('paper towels', 'vegetables', 'ketchup') , 0.133
# item: ('vegetables', 'waffles', 'sandwich bags') , 0.133
# item: ('vegetables', 'sugar', 'ice cream') , 0.133
# item: ('vegetables', 'yogurt', 'coffee/tea') , 0.133
# item: ('vegetables', 'waffles', 'all- purpose') , 0.133
# item: ('vegetables', 'waffles', 'ketchup') , 0.133
# item: ('vegetables', 'soap', 'sandwich loaves') , 0.133
# item: ('vegetables', 'individual meals', 'soda') , 0.133
# item: ('vegetables', 'laundry detergent', 'ketchup') , 0.133
# item: ('vegetables', 'shampoo', 'cereals') , 0.133
# item: ('vegetables', 'ketchup', 'poultry') , 0.133
# item: ('vegetables', 'bagels', 'waffles') , 0.133
# item: ('vegetables', 'fruits', 'cheeses') , 0.133
# item: ('vegetables', 'fruits', 'lunch meat') , 0.133
# item: ('vegetables', 'beef', 'ice cream') , 0.133
# item: ('vegetables', 'shampoo', 'lunch meat') , 0.133
# item: ('aluminum foil', 'vegetables', 'beef') , 0.133
# item: ('vegetables', 'fruits', 'ice cream') , 0.133
# item: ('vegetables', 'toilet paper', 'bagels') , 0.133
# item: ('vegetables', 'fruits', 'eggs') , 0.133
# item: ('vegetables', 'tortillas', 'eggs') , 0.133
# item: ('pasta', 'pork') , 0.133
# item: ('paper towels', 'hand soap') , 0.133
# item: ('juice', 'bagels', 'vegetables') , 0.133
# item: ('vegetables', 'cheeses', 'mixes') , 0.133
# item: ('vegetables', 'yogurt', 'sandwich loaves') , 0.133
# item: ('vegetables', 'individual meals', 'yogurt') , 0.133
# item: ('vegetables', 'laundry detergent', 'shampoo') , 0.133
# item: ('aluminum foil', 'vegetables', 'paper towels') , 0.133
# item: ('vegetables', 'individual meals', 'sandwich loaves') , 0.133
# item: ('vegetables', 'laundry detergent', 'butter') , 0.133
# item: ('vegetables', 'beef', 'cereals') , 0.133
# item: ('vegetables', 'ice cream', 'dishwashing liquid/detergent') , 0.133
# item: ('paper towels', 'soda', 'vegetables') , 0.133
# item: ('vegetables', 'sugar', 'dishwashing liquid/detergent') , 0.133
# item: ('vegetables', 'butter', 'poultry') , 0.133
# item: ('vegetables', 'soda', 'ice cream') , 0.133
# item: ('pasta', 'vegetables', 'ice cream') , 0.133
# item: ('juice', 'vegetables', 'ketchup') , 0.133
# item: ('paper towels', 'vegetables', 'juice') , 0.133
# item: ('vegetables', 'soap', 'cheeses') , 0.133
# item: ('aluminum foil', 'vegetables', 'cereals') , 0.133
# item: ('vegetables', 'ketchup', 'coffee/tea') , 0.133
# item: ('vegetables', 'sugar', 'yogurt') , 0.133
# item: ('vegetables', 'coffee/tea', 'cheeses') , 0.133
# item: ('tortillas', 'shampoo') , 0.134
# item: ('eggs', 'sandwich loaves') , 0.134
# item: ('milk', 'sandwich loaves') , 0.134
# item: ('pasta', 'vegetables', 'poultry') , 0.134
# item: ('aluminum foil', 'laundry detergent', 'vegetables') , 0.134
# item: ('pasta', 'vegetables', 'cheeses') , 0.134
# item: ('vegetables', 'yogurt', 'sandwich bags') , 0.134
# item: ('vegetables', 'sandwich loaves', 'ice cream') , 0.134
# item: ('vegetables', 'soap', 'ice cream') , 0.134
# item: ('vegetables', 'waffles', 'cereals') , 0.134
# item: ('vegetables', 'soda', 'dishwashing liquid/detergent') , 0.134
# item: ('vegetables', 'ketchup', 'mixes') , 0.134
# item: ('vegetables', 'laundry detergent', 'spaghetti sauce') , 0.134
# item: ('aluminum foil', 'vegetables', 'dishwashing liquid/detergent') , 0.134
# item: ('juice', 'vegetables', 'lunch meat') , 0.134
# item: ('vegetables', 'toilet paper', 'cereals') , 0.134
# item: ('vegetables', 'laundry detergent', 'waffles') , 0.134
# item: ('vegetables', 'laundry detergent', 'mixes') , 0.134
# item: ('vegetables', 'eggs', 'individual meals') , 0.134
# item: ('cheeses', 'vegetables', 'spaghetti sauce') , 0.134
# item: ('vegetables', 'individual meals', 'bagels') , 0.134
# item: ('vegetables', 'dinner rolls', 'mixes') , 0.134
# item: ('beef', 'flour') , 0.135
# item: ('soap', 'hand soap') , 0.135
# item: ('vegetables', 'lunch meat', 'cheeses') , 0.135
# item: ('vegetables', 'beef', 'poultry') , 0.135
# item: ('pasta', 'vegetables', 'yogurt') , 0.135
# item: ('pasta', 'vegetables', 'spaghetti sauce') , 0.135
# item: ('vegetables', 'fruits', 'bagels') , 0.135
# item: ('vegetables', 'milk', 'cereals') , 0.135
# item: ('paper towels', 'vegetables', 'yogurt') , 0.135
# item: ('paper towels', 'vegetables', 'cereals') , 0.135
# item: ('paper towels', 'vegetables', 'lunch meat') , 0.135
# item: ('vegetables', 'cheeses', 'ketchup') , 0.135
# item: ('vegetables', 'soap', 'ketchup') , 0.135
# item: ('vegetables', 'toilet paper', 'waffles') , 0.135
# item: ('vegetables', 'sandwich bags', 'ketchup') , 0.135
# item: ('juice', 'fruits') , 0.136
# item: ('paper towels', 'pork') , 0.136
# item: ('butter', 'flour') , 0.136
# item: ('bagels', 'flour') , 0.136
# item: ('hand soap', 'all- purpose') , 0.136
# item: ('pork', 'butter') , 0.136
# item: ('yogurt', 'hand soap') , 0.136
# item: ('vegetables', 'lunch meat', 'soda') , 0.136
# item: ('vegetables', 'soda', 'sugar') , 0.136
# item: ('vegetables', 'coffee/tea', 'eggs') , 0.136
# item: ('juice', 'vegetables', 'toilet paper') , 0.136
# item: ('vegetables', 'yogurt', 'bagels') , 0.136
# item: ('vegetables', 'eggs', 'butter') , 0.136
# item: ('vegetables', 'coffee/tea', 'cereals') , 0.136
# item: ('vegetables', 'laundry detergent', 'juice') , 0.136
# item: ('vegetables', 'sugar', 'waffles') , 0.136
# item: ('pasta', 'vegetables', 'cereals') , 0.136
# item: ('vegetables', 'laundry detergent', 'milk') , 0.136
# item: ('vegetables', 'coffee/tea', 'lunch meat') , 0.136
# item: ('sandwich bags', 'flour') , 0.137
# item: ('sugar', 'sandwich loaves') , 0.137
# item: ('vegetables', 'yogurt', 'spaghetti sauce') , 0.137
# item: ('aluminum foil', 'vegetables', 'lunch meat') , 0.137
# item: ('vegetables', 'dinner rolls', 'cheeses') , 0.137
# item: ('vegetables', 'waffles', 'coffee/tea') , 0.137
# item: ('vegetables', 'spaghetti sauce', 'cereals') , 0.137
# item: ('vegetables', 'laundry detergent', 'soda') , 0.137
# item: ('vegetables', 'laundry detergent', 'dishwashing liquid/detergent') , 0.137
# item: ('vegetables', 'eggs', 'toilet paper') , 0.137
# item: ('vegetables', 'tortillas', 'poultry') , 0.137
# item: ('vegetables', 'yogurt', 'mixes') , 0.137
# item: ('vegetables', 'soap', 'spaghetti sauce') , 0.137
# item: ('vegetables', 'laundry detergent', 'all- purpose') , 0.137
# item: ('vegetables', 'milk', 'soda') , 0.137
# item: ('paper towels', 'vegetables', 'poultry') , 0.137
# item: ('vegetables', 'dinner rolls', 'shampoo') , 0.137
# item: ('aluminum foil', 'vegetables', 'shampoo') , 0.137
# item: ('juice', 'vegetables', 'waffles') , 0.137
# item: ('sugar', 'hand soap') , 0.138
# item: ('sugar', 'mixes') , 0.138
# item: ('tortillas', 'hand soap') , 0.138
# item: ('fruits', 'hand soap') , 0.138
# item: ('fruits', 'flour') , 0.138
# item: ('juice', 'flour') , 0.138
# item: ('sugar', 'butter') , 0.138
# item: ('shampoo', 'hand soap') , 0.138
# item: ('sandwich bags', 'sandwich loaves') , 0.138
# item: ('juice', 'hand soap') , 0.138
# item: ('toilet paper', 'pork') , 0.138
# item: ('vegetables', 'waffles', 'spaghetti sauce') , 0.138
# item: ('vegetables', 'yogurt', 'beef') , 0.138
# item: ('vegetables', 'milk', 'dishwashing liquid/detergent') , 0.138
# item: ('juice', 'vegetables', 'shampoo') , 0.138
# item: ('vegetables', 'soap', 'lunch meat') , 0.138
# item: ('vegetables', 'sugar', 'dinner rolls') , 0.138
# item: ('vegetables', 'bagels', 'poultry') , 0.138
# item: ('paper towels', 'vegetables', 'ice cream') , 0.138
# item: ('aluminum foil', 'vegetables', 'eggs') , 0.138
# item: ('vegetables', 'eggs', 'ice cream') , 0.138
# item: ('vegetables', 'laundry detergent', 'cheeses') , 0.138
# item: ('vegetables', 'cheeses', 'cereals') , 0.138
# item: ('vegetables', 'laundry detergent', 'ice cream') , 0.138
# item: ('vegetables', 'fruits', 'dishwashing liquid/detergent') , 0.138
# item: ('hand soap', 'sandwich loaves') , 0.139
# item: ('aluminum foil', 'hand soap') , 0.139
# item: ('soda', 'hand soap') , 0.139
# item: ('fruits', 'toilet paper') , 0.139
# item: ('individual meals', 'hand soap') , 0.139
# item: ('cheeses', 'hand soap') , 0.139
# item: ('sugar', 'ketchup') , 0.139
# item: ('hand soap', 'ketchup') , 0.139
# item: ('paper towels', 'flour') , 0.139
# item: ('sandwich bags', 'hand soap') , 0.139
# item: ('toilet paper', 'hand soap') , 0.139
# item: ('hand soap', 'cereals') , 0.139
# item: ('vegetables', 'individual meals', 'poultry') , 0.139
# item: ('vegetables', 'lunch meat', 'spaghetti sauce') , 0.139
# item: ('vegetables', 'dinner rolls', 'dishwashing liquid/detergent') , 0.139
# item: ('vegetables', 'cheeses', 'soda') , 0.139
# item: ('vegetables', 'poultry', 'sandwich bags') , 0.139
# item: ('vegetables', 'dishwashing liquid/detergent', 'cereals') , 0.139
# item: ('vegetables', 'dinner rolls', 'lunch meat') , 0.139
# item: ('vegetables', 'spaghetti sauce', 'bagels') , 0.139
# item: ('aluminum foil', 'soda', 'vegetables') , 0.139
# item: ('vegetables', 'spaghetti sauce', 'soda') , 0.139
# item: ('vegetables', 'poultry', 'all- purpose') , 0.139
# item: ('vegetables', 'eggs', 'spaghetti sauce') , 0.139
# item: ('paper towels', 'sandwich loaves') , 0.140
# item: ('milk', 'butter') , 0.140
# item: ('fruits', 'sandwich loaves') , 0.140
# item: ('shampoo', 'spaghetti sauce') , 0.140
# item: ('yogurt', 'butter') , 0.140
# item: ('coffee/tea', 'hand soap') , 0.140
# item: ('individual meals', 'all- purpose') , 0.140
# item: ('vegetables', 'waffles', 'ice cream') , 0.140
# item: ('vegetables', 'yogurt', 'laundry detergent') , 0.140
# item: ('aluminum foil', 'vegetables', 'dinner rolls') , 0.140
# item: ('vegetables', 'waffles', 'poultry') , 0.140
# item: ('fruits', 'shampoo') , 0.140
# item: ('sugar', 'milk') , 0.140
# item: ('pasta', 'butter') , 0.140
# item: ('laundry detergent', 'pork') , 0.140
# item: ('pork', 'ice cream') , 0.140
# item: ('vegetables', 'laundry detergent', 'eggs') , 0.140
# item: ('vegetables', 'yogurt', 'lunch meat') , 0.140
# item: ('vegetables', 'lunch meat', 'cereals') , 0.140
# item: ('vegetables', 'eggs', 'all- purpose') , 0.140
# item: ('vegetables', 'laundry detergent', 'sandwich bags') , 0.140
# item: ('vegetables', 'eggs', 'lunch meat') , 0.140
# item: ('vegetables', 'eggs', 'ketchup') , 0.140
# item: ('vegetables', 'soap', 'waffles') , 0.140
# item: ('aluminum foil', 'vegetables', 'cheeses') , 0.140
# item: ('vegetables', 'yogurt', 'dishwashing liquid/detergent') , 0.140
# item: ('vegetables', 'eggs', 'beef') , 0.140
# item: ('sandwich loaves', 'flour') , 0.141
# item: ('coffee/tea', 'beef') , 0.141
# item: ('tortillas', 'beef') , 0.141
# item: ('fruits', 'butter') , 0.141
# item: ('pasta', 'sandwich loaves') , 0.141
# item: ('laundry detergent', 'beef') , 0.141
# item: ('paper towels', 'sugar') , 0.141
# item: ('individual meals', 'pork') , 0.141
# item: ('soda', 'sandwich loaves') , 0.141
# item: ('butter', 'sandwich loaves') , 0.141
# item: ('fruits', 'tortillas') , 0.141
# item: ('vegetables', 'dinner rolls', 'yogurt') , 0.141
# item: ('juice', 'vegetables', 'spaghetti sauce') , 0.141
# item: ('mixes', 'vegetables', 'cereals') , 0.141
# item: ('aluminum foil', 'vegetables', 'waffles') , 0.141
# item: ('vegetables', 'dinner rolls', 'cereals') , 0.141
# item: ('pasta', 'vegetables', 'dinner rolls') , 0.141
# item: ('vegetables', 'sugar', 'lunch meat') , 0.141
# item: ('vegetables', 'soda', 'soap') , 0.141
# item: ('vegetables', 'sandwich loaves', 'poultry') , 0.141
# item: ('pasta', 'vegetables', 'soda') , 0.141
# item: ('aluminum foil', 'sugar') , 0.142
# item: ('toilet paper', 'flour') , 0.142
# item: ('individual meals', 'flour') , 0.142
# item: ('paper towels', 'tortillas') , 0.142
# item: ('sandwich loaves', 'all- purpose') , 0.142
# item: ('coffee/tea', 'sugar') , 0.142
# item: ('beef', 'sandwich loaves') , 0.142
# item: ('shampoo', 'pork') , 0.142
# item: ('tortillas', 'flour') , 0.142
# item: ('pasta', 'lunch meat') , 0.142
# item: ('tortillas', 'sandwich loaves') , 0.142
# item: ('flour', 'all- purpose') , 0.142
# item: ('toilet paper', 'sandwich loaves') , 0.142
# item: ('pork', 'spaghetti sauce') , 0.142
# item: ('individual meals', 'ketchup') , 0.142
# item: ('vegetables', 'shampoo', 'poultry') , 0.142
# item: ('vegetables', 'yogurt', 'cereals') , 0.142
# item: ('vegetables', 'bagels', 'dishwashing liquid/detergent') , 0.142
# item: ('vegetables', 'yogurt', 'all- purpose') , 0.142
# item: ('vegetables', 'soda', 'waffles') , 0.142
# item: ('coffee/tea', 'butter') , 0.143
# item: ('laundry detergent', 'hand soap') , 0.143
# item: ('shampoo', 'flour') , 0.143
# item: ('hand soap', 'dishwashing liquid/detergent') , 0.143
# item: ('hand soap', 'ice cream') , 0.143
# item: ('lunch meat', 'hand soap') , 0.143
# item: ('juice', 'sugar') , 0.143
# item: ('sandwich bags', 'all- purpose') , 0.143
# item: ('milk', 'pork') , 0.143
# item: ('dinner rolls', 'pork') , 0.143
# item: ('juice', 'tortillas') , 0.143
# item: ('milk', 'waffles') , 0.143
# item: ('butter', 'ketchup') , 0.143
# item: ('waffles', 'hand soap') , 0.143
# item: ('lunch meat', 'ketchup') , 0.143
# item: ('paper towels', 'vegetables', 'eggs') , 0.143
# item: ('vegetables', 'dinner rolls', 'spaghetti sauce') , 0.143
# item: ('vegetables', 'individual meals', 'lunch meat') , 0.143
# item: ('vegetables', 'laundry detergent', 'dinner rolls') , 0.143
# item: ('vegetables', 'toilet paper', 'poultry') , 0.143
# item: ('vegetables', 'lunch meat', 'dishwashing liquid/detergent') , 0.143
# item: ('vegetables', 'yogurt', 'soda') , 0.143
# item: ('coffee/tea', 'fruits') , 0.144
# item: ('eggs', 'hand soap') , 0.144
# item: ('sandwich bags', 'individual meals') , 0.144
# item: ('sugar', 'flour') , 0.144
# item: ('paper towels', 'butter') , 0.144
# item: ('pasta', 'fruits') , 0.144
# item: ('beef', 'hand soap') , 0.144
# item: ('vegetables', 'yogurt', 'cheeses') , 0.144
# item: ('vegetables', 'cheeses', 'poultry') , 0.144
# item: ('vegetables', 'waffles', 'dishwashing liquid/detergent') , 0.144
# item: ('aluminum foil', 'vegetables', 'juice') , 0.144
# item: ('pasta', 'vegetables', 'eggs') , 0.144
# item: ('vegetables', 'waffles', 'cheeses') , 0.144
# item: ('juice', 'vegetables', 'eggs') , 0.144
# item: ('vegetables', 'soda', 'poultry') , 0.144
# item: ('vegetables', 'sandwich bags', 'cheeses') , 0.144
# item: ('vegetables', 'dishwashing liquid/detergent', 'mixes') , 0.144
# item: ('vegetables', 'poultry', 'coffee/tea') , 0.144
# item: ('beef', 'mixes') , 0.145
# item: ('sugar', 'spaghetti sauce') , 0.145
# item: ('spaghetti sauce', 'hand soap') , 0.145
# item: ('pork', 'flour') , 0.145
# item: ('soap', 'pork') , 0.145
# item: ('individual meals', 'fruits') , 0.145
# item: ('juice', 'sandwich loaves') , 0.145
# item: ('beef', 'all- purpose') , 0.145
# item: ('sandwich bags', 'toilet paper') , 0.145
# item: ('ice cream', 'flour') , 0.145
# item: ('waffles', 'flour') , 0.145
# item: ('individual meals', 'milk') , 0.145
# item: ('bagels', 'sandwich loaves') , 0.145
# item: ('tortillas', 'cheeses') , 0.145
# item: ('coffee/tea', 'spaghetti sauce') , 0.145
# item: ('vegetables', 'milk', 'eggs') , 0.145
# item: ('vegetables', 'eggs', 'waffles') , 0.145
# item: ('vegetables', 'cheeses', 'ice cream') , 0.145
# item: ('vegetables', 'bagels', 'eggs') , 0.145
# item: ('vegetables', 'milk', 'yogurt') , 0.145
# item: ('vegetables', 'spaghetti sauce', 'poultry') , 0.145
# item: ('milk', 'flour') , 0.146
# item: ('tortillas', 'all- purpose') , 0.146
# item: ('coffee/tea', 'sandwich loaves') , 0.146
# item: ('coffee/tea', 'laundry detergent') , 0.146
# item: ('shampoo', 'dishwashing liquid/detergent') , 0.146
# item: ('laundry detergent', 'flour') , 0.146
# item: ('laundry detergent', 'tortillas') , 0.146
# item: ('shampoo', 'butter') , 0.146
# item: ('sugar', 'all- purpose') , 0.146
# item: ('bagels', 'soap') , 0.146
# item: ('tortillas', 'ketchup') , 0.146
# item: ('sugar', 'fruits') , 0.146
# item: ('sandwich bags', 'eggs') , 0.146
# item: ('aluminum foil', 'tortillas') , 0.146
# item: ('aluminum foil', 'vegetables', 'ice cream') , 0.146
# item: ('vegetables', 'eggs', 'soap') , 0.146
# item: ('aluminum foil', 'vegetables', 'mixes') , 0.146
# item: ('lunch meat', 'sandwich loaves') , 0.147
# item: ('coffee/tea', 'all- purpose') , 0.147
# item: ('pasta', 'beef') , 0.147
# item: ('tortillas', 'butter') , 0.147
# item: ('aluminum foil', 'pork') , 0.147
# item: ('waffles', 'sandwich loaves') , 0.147
# item: ('fruits', 'milk') , 0.147
# item: ('sandwich bags', 'shampoo') , 0.147
# item: ('pasta', 'individual meals') , 0.147
# item: ('spaghetti sauce', 'dishwashing liquid/detergent') , 0.147
# item: ('pasta', 'mixes') , 0.147
# item: ('juice', 'sandwich bags') , 0.147
# item: ('cereals', 'flour') , 0.147
# item: ('vegetables', 'milk', 'poultry') , 0.147
# item: ('juice', 'vegetables', 'yogurt') , 0.147
# item: ('vegetables', 'lunch meat', 'ice cream') , 0.147
# item: ('vegetables', 'waffles', 'yogurt') , 0.147
# item: ('juice', 'vegetables', 'poultry') , 0.147
# item: ('vegetables', 'dinner rolls', 'soda') , 0.147
# item: ('aluminum foil', 'vegetables', 'bagels') , 0.147
# item: ('vegetables', 'soap', 'poultry') , 0.147
# item: ('aluminum foil', 'butter') , 0.147
# item: ('soap', 'mixes') , 0.147
# item: ('fruits', 'dinner rolls') , 0.147
# item: ('pasta', 'sandwich bags') , 0.147
# item: ('butter', 'all- purpose') , 0.147
# item: ('tortillas', 'pork') , 0.147
# item: ('juice', 'butter') , 0.147
# item: ('individual meals', 'beef') , 0.147
# item: ('paper towels', 'laundry detergent') , 0.147
# item: ('sugar', 'shampoo') , 0.147
# item: ('individual meals', 'butter') , 0.147
# item: ('juice', 'mixes') , 0.147
# item: ('tortillas', 'ice cream') , 0.147
# item: ('sandwich loaves', 'mixes') , 0.147
# item: ('sugar', 'tortillas') , 0.147
# item: ('fruits', 'ketchup') , 0.147
# item: ('sandwich bags', 'spaghetti sauce') , 0.147
# item: ('vegetables', 'dinner rolls', 'waffles') , 0.147
# item: ('pasta', 'flour') , 0.148
# item: ('cheeses', 'all- purpose') , 0.148
# item: ('tortillas', 'soap') , 0.148
# item: ('coffee/tea', 'pork') , 0.148
# item: ('soda', 'pork') , 0.148
# item: ('laundry detergent', 'fruits') , 0.148
# item: ('ketchup', 'flour') , 0.148
# item: ('coffee/tea', 'mixes') , 0.148
# item: ('milk', 'hand soap') , 0.148
# item: ('pasta', 'hand soap') , 0.148
# item: ('tortillas', 'spaghetti sauce') , 0.148
# item: ('ketchup', 'cereals') , 0.148
# item: ('fruits', 'soap') , 0.148
# item: ('soap', 'butter') , 0.148
# item: ('individual meals', 'sugar') , 0.148
# item: ('vegetables', 'poultry', 'cereals') , 0.148
# item: ('vegetables', 'poultry', 'ice cream') , 0.148
# item: ('aluminum foil', 'vegetables', 'poultry') , 0.148
# item: ('dinner rolls', 'sandwich loaves') , 0.149
# item: ('butter', 'dishwashing liquid/detergent') , 0.149
# item: ('laundry detergent', 'sugar') , 0.149
# item: ('eggs', 'flour') , 0.149
# item: ('soda', 'all- purpose') , 0.149
# item: ('pasta', 'juice') , 0.149
# item: ('individual meals', 'dinner rolls') , 0.149
# item: ('pasta', 'toilet paper') , 0.149
# item: ('spaghetti sauce', 'all- purpose') , 0.149
# item: ('milk', 'shampoo') , 0.149
# item: ('sandwich loaves', 'cereals') , 0.149
# item: ('individual meals', 'mixes') , 0.149
# item: ('pork', 'lunch meat') , 0.149
# item: ('fruits', 'mixes') , 0.149
# item: ('tortillas', 'waffles') , 0.149
# item: ('soap', 'yogurt') , 0.149
# item: ('toilet paper', 'mixes') , 0.149
# item: ('vegetables', 'laundry detergent', 'poultry') , 0.149
# item: ('juice', 'cheeses') , 0.150
# item: ('soda', 'mixes') , 0.150
# item: ('paper towels', 'sandwich bags') , 0.150
# item: ('bagels', 'all- purpose') , 0.150
# item: ('shampoo', 'ice cream') , 0.150
# item: ('butter', 'spaghetti sauce') , 0.150
# item: ('aluminum foil', 'sandwich loaves') , 0.150
# item: ('shampoo', 'sandwich loaves') , 0.150
# item: ('spaghetti sauce', 'sandwich loaves') , 0.150
# item: ('butter', 'cereals') , 0.150
# item: ('pork', 'beef') , 0.150
# item: ('flour', 'mixes') , 0.150
# item: ('paper towels', 'fruits') , 0.150
# item: ('sandwich bags', 'pork') , 0.150
# item: ('pork', 'cereals') , 0.150
# item: ('pork', 'cheeses') , 0.150
# item: ('dinner rolls', 'toilet paper') , 0.150
# item: ('soda', 'fruits') , 0.150
# item: ('soda', 'shampoo') , 0.150
# item: ('fruits', 'all- purpose') , 0.150
# item: ('vegetables', 'eggs', 'cheeses') , 0.150
# item: ('soap', 'shampoo') , 0.151
# item: ('sugar', 'eggs') , 0.151
# item: ('eggs', 'shampoo') , 0.151
# item: ('shampoo', 'ketchup') , 0.151
# item: ('pork', 'yogurt') , 0.151
# item: ('pasta', 'sugar') , 0.151
# item: ('cereals', 'all- purpose') , 0.151
# item: ('paper towels', 'cheeses') , 0.151
# item: ('pasta', 'milk') , 0.151
# item: ('soap', 'flour') , 0.151
# item: ('pasta', 'shampoo') , 0.151
# item: ('eggs', 'pork') , 0.151
# item: ('bagels', 'sugar') , 0.151
# item: ('aluminum foil', 'sandwich bags') , 0.151
# item: ('vegetables', 'laundry detergent', 'cereals') , 0.151
# item: ('vegetables', 'eggs', 'cereals') , 0.151
# item: ('sugar', 'dishwashing liquid/detergent') , 0.152
# item: ('coffee/tea', 'milk') , 0.152
# item: ('bagels', 'butter') , 0.152
# item: ('tortillas', 'milk') , 0.152
# item: ('pasta', 'bagels') , 0.152
# item: ('paper towels', 'yogurt') , 0.152
# item: ('flour', 'dishwashing liquid/detergent') , 0.152
# item: ('shampoo', 'all- purpose') , 0.152
# item: ('fruits', 'eggs') , 0.152
# item: ('milk', 'all- purpose') , 0.152
# item: ('pork', 'waffles') , 0.152
# item: ('laundry detergent', 'individual meals') , 0.152
# item: ('waffles', 'butter') , 0.152
# item: ('individual meals', 'shampoo') , 0.152
# item: ('coffee/tea', 'bagels') , 0.152
# item: ('all- purpose', 'mixes') , 0.152
# item: ('coffee/tea', 'flour') , 0.152
# item: ('tortillas', 'dishwashing liquid/detergent') , 0.152
# item: ('toilet paper', 'spaghetti sauce') , 0.152
# item: ('sugar', 'toilet paper') , 0.152
# item: ('dinner rolls', 'butter') , 0.152
# item: ('hand soap', 'mixes') , 0.152
# item: ('aluminum foil', 'vegetables', 'yogurt') , 0.152
# item: ('vegetables', 'sugar', 'poultry') , 0.152
# item: ('coffee/tea', 'shampoo') , 0.153
# item: ('juice', 'dishwashing liquid/detergent') , 0.153
# item: ('coffee/tea', 'individual meals') , 0.153
# item: ('sandwich bags', 'lunch meat') , 0.153
# item: ('yogurt', 'sandwich loaves') , 0.153
# item: ('individual meals', 'tortillas') , 0.153
# item: ('toilet paper', 'dishwashing liquid/detergent') , 0.153
# item: ('coffee/tea', 'sandwich bags') , 0.153
# item: ('butter', 'mixes') , 0.153
# item: ('paper towels', 'ketchup') , 0.153
# item: ('individual meals', 'toilet paper') , 0.153
# item: ('yogurt', 'ketchup') , 0.153
# item: ('pasta', 'tortillas') , 0.153
# item: ('sandwich bags', 'dinner rolls') , 0.153
# item: ('laundry detergent', 'bagels') , 0.153
# item: ('pork', 'dishwashing liquid/detergent') , 0.153
# item: ('laundry detergent', 'toilet paper') , 0.153
# item: ('tortillas', 'yogurt') , 0.153
# item: ('sandwich loaves', 'ketchup') , 0.153
# item: ('sugar', 'cheeses') , 0.153
# item: ('vegetables', 'yogurt', 'poultry') , 0.153
# item: ('pork', 'ketchup') , 0.154
# item: ('pork', 'all- purpose') , 0.154
# item: ('coffee/tea', 'dishwashing liquid/detergent') , 0.154
# item: ('paper towels', 'bagels') , 0.154
# item: ('pasta', 'laundry detergent') , 0.154
# item: ('laundry detergent', 'shampoo') , 0.154
# item: ('sandwich bags', 'butter') , 0.154
# item: ('butter', 'ice cream') , 0.154
# item: ('ice cream', 'mixes') , 0.154
# item: ('lunch meat', 'mixes') , 0.154
# item: ('shampoo', 'beef') , 0.154
# item: ('dinner rolls', 'hand soap') , 0.154
# item: ('juice', 'milk') , 0.154
# item: ('juice', 'all- purpose') , 0.154
# item: ('sandwich bags', 'fruits') , 0.154
# item: ('paper towels', 'coffee/tea') , 0.154
# item: ('toilet paper', 'all- purpose') , 0.154
# item: ('individual meals', 'eggs') , 0.154
# item: ('sandwich bags', 'dishwashing liquid/detergent') , 0.154
# item: ('vegetables', 'eggs', 'dishwashing liquid/detergent') , 0.154
# item: ('paper towels', 'soap') , 0.155
# item: ('coffee/tea', 'tortillas') , 0.155
# item: ('sugar', 'soap') , 0.155
# item: ('dinner rolls', 'flour') , 0.155
# item: ('paper towels', 'individual meals') , 0.155
# item: ('hand soap', 'poultry') , 0.155
# item: ('dinner rolls', 'beef') , 0.155
# item: ('laundry detergent', 'soap') , 0.155
# item: ('sandwich bags', 'bagels') , 0.155
# item: ('waffles', 'mixes') , 0.155
# item: ('sandwich bags', 'yogurt') , 0.155
# item: ('ketchup', 'all- purpose') , 0.155
# item: ('aluminum foil', 'flour') , 0.155
# item: ('soda', 'butter') , 0.155
# item: ('spaghetti sauce', 'ketchup') , 0.155
# item: ('toilet paper', 'butter') , 0.155
# item: ('bagels', 'dinner rolls') , 0.155
# item: ('beef', 'ketchup') , 0.155
# item: ('paper towels', 'beef') , 0.155
# item: ('yogurt', 'ice cream') , 0.155
# item: ('pork', 'mixes') , 0.155
# item: ('paper towels', 'dinner rolls') , 0.155
# item: ('bagels', 'pork') , 0.155
# item: ('soda', 'tortillas') , 0.155
# item: ('juice', 'laundry detergent') , 0.155
# item: ('sugar', 'beef') , 0.155
# item: ('soda', 'beef') , 0.155
# item: ('juice', 'beef') , 0.155
# item: ('juice', 'individual meals') , 0.155
# item: ('cheeses', 'sandwich loaves') , 0.155
# item: ('ketchup', 'dishwashing liquid/detergent') , 0.155
# item: ('fruits', 'spaghetti sauce') , 0.155
# item: ('dinner rolls', 'all- purpose') , 0.155
# item: ('sandwich bags', 'mixes') , 0.155
# item: ('paper towels', 'shampoo') , 0.155
# item: ('pasta', 'coffee/tea') , 0.155
# item: ('shampoo', 'waffles') , 0.155
# item: ('vegetables', 'eggs', 'poultry') , 0.155
# item: ('paper towels', 'waffles') , 0.156
# item: ('bagels', 'beef') , 0.156
# item: ('lunch meat', 'flour') , 0.156
# item: ('tortillas', 'toilet paper') , 0.156
# item: ('sandwich bags', 'ice cream') , 0.156
# item: ('paper towels', 'all- purpose') , 0.156
# item: ('coffee/tea', 'toilet paper') , 0.156
# item: ('milk', 'ketchup') , 0.156
# item: ('pasta', 'ketchup') , 0.156
# item: ('aluminum foil', 'spaghetti sauce') , 0.156
# item: ('juice', 'coffee/tea') , 0.156
# item: ('juice', 'soap') , 0.156
# item: ('paper towels', 'spaghetti sauce') , 0.156
# item: ('soap', 'dinner rolls') , 0.156
# item: ('milk', 'cheeses') , 0.156
# item: ('milk', 'dinner rolls') , 0.156
# item: ('soda', 'cereals') , 0.156
# item: ('sandwich bags', 'beef') , 0.156
# item: ('laundry detergent', 'waffles') , 0.156
# item: ('juice', 'pork') , 0.156
# item: ('sugar', 'cereals') , 0.156
# item: ('individual meals', 'waffles') , 0.156
# item: ('toilet paper', 'ketchup') , 0.156
# item: ('juice', 'cereals') , 0.156
# item: ('yogurt', 'flour') , 0.156
# item: ('ketchup', 'ice cream') , 0.156
# item: ('shampoo', 'mixes') , 0.156
# item: ('vegetables', 'eggs', 'dinner rolls') , 0.156
# item: ('vegetables', 'poultry', 'mixes') , 0.156
# item: ('soda', 'bagels') , 0.157
# item: ('poultry', 'flour') , 0.157
# item: ('aluminum foil', 'soap') , 0.157
# item: ('toilet paper', 'beef') , 0.157
# item: ('ice cream', 'all- purpose') , 0.157
# item: ('juice', 'dinner rolls') , 0.157
# item: ('beef', 'dishwashing liquid/detergent') , 0.157
# item: ('juice', 'soda') , 0.157
# item: ('toilet paper', 'shampoo') , 0.157
# item: ('aluminum foil', 'eggs') , 0.157
# item: ('pasta', 'aluminum foil') , 0.157
# item: ('laundry detergent', 'lunch meat') , 0.157
# item: ('sugar', 'ice cream') , 0.157
# item: ('aluminum foil', 'all- purpose') , 0.157
# item: ('waffles', 'beef') , 0.157
# item: ('laundry detergent', 'ketchup') , 0.157
# item: ('vegetables', 'waffles', 'lunch meat') , 0.157
# item: ('vegetables', 'eggs', 'yogurt') , 0.157
# item: ('bagels', 'shampoo') , 0.158
# item: ('individual meals', 'yogurt') , 0.158
# item: ('paper towels', 'mixes') , 0.158
# item: ('beef', 'spaghetti sauce') , 0.158
# item: ('tortillas', 'dinner rolls') , 0.158
# item: ('milk', 'spaghetti sauce') , 0.158
# item: ('aluminum foil', 'ketchup') , 0.158
# item: ('yogurt', 'dishwashing liquid/detergent') , 0.158
# item: ('aluminum foil', 'fruits') , 0.158
# item: ('beef', 'lunch meat') , 0.158
# item: ('soda', 'ketchup') , 0.158
# item: ('shampoo', 'cheeses') , 0.158
# item: ('individual meals', 'spaghetti sauce') , 0.158
# item: ('sandwich bags', 'milk') , 0.158
# item: ('soda', 'flour') , 0.158
# item: ('laundry detergent', 'yogurt') , 0.158
# item: ('soap', 'sandwich loaves') , 0.158
# item: ('sandwich loaves', 'ice cream') , 0.158
# item: ('bagels', 'lunch meat') , 0.158
# item: ('bagels', 'ketchup') , 0.158
# item: ('sandwich bags', 'cereals') , 0.158
# item: ('dinner rolls', 'ketchup') , 0.158
# item: ('fruits', 'yogurt') , 0.158
# item: ('laundry detergent', 'butter') , 0.158
# item: ('shampoo', 'yogurt') , 0.158
# item: ('spaghetti sauce', 'mixes') , 0.158
# item: ('vegetables', 'eggs', 'soda') , 0.158
# item: ('vegetables', 'lunch meat', 'poultry') , 0.158
# item: ('eggs', 'mixes') , 0.159
# item: ('spaghetti sauce', 'ice cream') , 0.159
# item: ('eggs', 'butter') , 0.159
# item: ('coffee/tea', 'soda') , 0.159
# item: ('paper towels', 'juice') , 0.159
# item: ('coffee/tea', 'dinner rolls') , 0.159
# item: ('sugar', 'yogurt') , 0.159
# item: ('paper towels', 'dishwashing liquid/detergent') , 0.159
# item: ('aluminum foil', 'coffee/tea') , 0.159
# item: ('coffee/tea', 'eggs') , 0.159
# item: ('shampoo', 'cereals') , 0.159
# item: ('individual meals', 'dishwashing liquid/detergent') , 0.159
# item: ('sandwich bags', 'soap') , 0.159
# item: ('sandwich bags', 'waffles') , 0.159
# item: ('eggs', 'lunch meat') , 0.159
# item: ('aluminum foil', 'dishwashing liquid/detergent') , 0.159
# item: ('paper towels', 'poultry') , 0.159
# item: ('pasta', 'yogurt') , 0.159
# item: ('coffee/tea', 'soap') , 0.159
# item: ('aluminum foil', 'shampoo') , 0.159
# item: ('milk', 'mixes') , 0.159
# item: ('tortillas', 'cereals') , 0.159
# item: ('laundry detergent', 'ice cream') , 0.159
# item: ('tortillas', 'eggs') , 0.159
# item: ('butter', 'cheeses') , 0.160
# item: ('individual meals', 'soap') , 0.160
# item: ('pasta', 'spaghetti sauce') , 0.160
# item: ('bagels', 'ice cream') , 0.160
# item: ('bagels', 'waffles') , 0.160
# item: ('butter', 'lunch meat') , 0.160
# item: ('soap', 'beef') , 0.160
# item: ('soap', 'dishwashing liquid/detergent') , 0.160
# item: ('aluminum foil', 'paper towels') , 0.160
# item: ('individual meals', 'sandwich loaves') , 0.160
# item: ('cheeses', 'flour') , 0.160
# item: ('beef', 'cheeses') , 0.160
# item: ('sugar', 'waffles') , 0.160
# item: ('eggs', 'all- purpose') , 0.160
# item: ('shampoo', 'lunch meat') , 0.160
# item: ('pasta', 'cheeses') , 0.160
# item: ('laundry detergent', 'mixes') , 0.160
# item: ('soda', 'lunch meat') , 0.160
# item: ('pasta', 'all- purpose') , 0.160
# item: ('aluminum foil', 'beef') , 0.160
# item: ('lunch meat', 'all- purpose') , 0.160
# item: ('aluminum foil', 'toilet paper') , 0.160
# item: ('individual meals', 'cereals') , 0.160
# item: ('pasta', 'soap') , 0.160
# item: ('toilet paper', 'ice cream') , 0.160
# item: ('yogurt', 'spaghetti sauce') , 0.160
# item: ('vegetables', 'poultry', 'dishwashing liquid/detergent') , 0.160
# item: ('paper towels', 'soda') , 0.161
# item: ('aluminum foil', 'lunch meat') , 0.161
# item: ('aluminum foil', 'laundry detergent') , 0.161
# item: ('juice', 'ketchup') , 0.161
# item: ('all- purpose', 'dishwashing liquid/detergent') , 0.161
# item: ('individual meals', 'cheeses') , 0.161
# item: ('yogurt', 'lunch meat') , 0.161
# item: ('milk', 'lunch meat') , 0.161
# item: ('soap', 'spaghetti sauce') , 0.161
# item: ('laundry detergent', 'cheeses') , 0.161
# item: ('milk', 'beef') , 0.161
# item: ('aluminum foil', 'milk') , 0.161
# item: ('waffles', 'cereals') , 0.161
# item: ('sandwich bags', 'tortillas') , 0.161
# item: ('cheeses', 'ketchup') , 0.161
# item: ('coffee/tea', 'yogurt') , 0.161
# item: ('lunch meat', 'cheeses') , 0.161
# item: ('yogurt', 'beef') , 0.161
# item: ('paper towels', 'milk') , 0.162
# item: ('pasta', 'cereals') , 0.162
# item: ('milk', 'soap') , 0.162
# item: ('laundry detergent', 'spaghetti sauce') , 0.162
# item: ('bagels', 'milk') , 0.162
# item: ('beef', 'ice cream') , 0.162
# item: ('aluminum foil', 'soda') , 0.162
# item: ('pasta', 'dishwashing liquid/detergent') , 0.162
# item: ('waffles', 'ketchup') , 0.162
# item: ('dinner rolls', 'ice cream') , 0.162
# item: ('pasta', 'waffles') , 0.162
# item: ('pasta', 'poultry') , 0.162
# item: ('fruits', 'cereals') , 0.162
# item: ('paper towels', 'toilet paper') , 0.162
# item: ('sugar', 'lunch meat') , 0.162
# item: ('juice', 'lunch meat') , 0.162
# item: ('vegetables', 'dinner rolls', 'poultry') , 0.162
# item: ('soda', 'toilet paper') , 0.162
# item: ('toilet paper', 'yogurt') , 0.162
# item: ('juice', 'bagels') , 0.162
# item: ('soda', 'sugar') , 0.162
# item: ('bagels', 'tortillas') , 0.162
# item: ('dinner rolls', 'lunch meat') , 0.162
# item: ('dinner rolls', 'mixes') , 0.162
# item: ('soap', 'cheeses') , 0.162
# item: ('bagels', 'yogurt') , 0.162
# item: ('bagels', 'cereals') , 0.162
# item: ('soda', 'sandwich bags') , 0.162
# item: ('soap', 'cereals') , 0.162
# item: ('tortillas', 'mixes') , 0.162
# item: ('laundry detergent', 'all- purpose') , 0.162
# item: ('individual meals', 'ice cream') , 0.162
# item: ('aluminum foil', 'individual meals') , 0.162
# item: ('fruits', 'cheeses') , 0.163
# item: ('laundry detergent', 'soda') , 0.163
# item: ('soap', 'all- purpose') , 0.163
# item: ('milk', 'toilet paper') , 0.163
# item: ('poultry', 'sandwich loaves') , 0.163
# item: ('laundry detergent', 'sandwich bags') , 0.163
# item: ('fruits', 'lunch meat') , 0.163
# item: ('tortillas', 'lunch meat') , 0.163
# item: ('eggs', 'spaghetti sauce') , 0.163
# item: ('eggs', 'beef') , 0.163
# item: ('laundry detergent', 'dishwashing liquid/detergent') , 0.163
# item: ('cheeses', 'mixes') , 0.163
# item: ('fruits', 'waffles') , 0.163
# item: ('eggs', 'toilet paper') , 0.163
# item: ('laundry detergent', 'eggs') , 0.163
# item: ('cheeses', 'dishwashing liquid/detergent') , 0.163
# item: ('bagels', 'toilet paper') , 0.163
# item: ('toilet paper', 'lunch meat') , 0.164
# item: ('sandwich bags', 'ketchup') , 0.164
# item: ('paper towels', 'cereals') , 0.164
# item: ('bagels', 'mixes') , 0.164
# item: ('waffles', 'spaghetti sauce') , 0.164
# item: ('soap', 'toilet paper') , 0.164
# item: ('yogurt', 'mixes') , 0.164
# item: ('sugar', 'dinner rolls') , 0.164
# item: ('coffee/tea', 'ketchup') , 0.164
# item: ('soap', 'ketchup') , 0.164
# item: ('pasta', 'paper towels') , 0.164
# item: ('pork', 'poultry') , 0.164
# item: ('juice', 'eggs') , 0.165
# item: ('laundry detergent', 'dinner rolls') , 0.165
# item: ('dinner rolls', 'dishwashing liquid/detergent') , 0.165
# item: ('coffee/tea', 'ice cream') , 0.165
# item: ('individual meals', 'bagels') , 0.165
# item: ('milk', 'ice cream') , 0.165
# item: ('ice cream', 'dishwashing liquid/detergent') , 0.165
# item: ('fruits', 'ice cream') , 0.165
# item: ('ketchup', 'mixes') , 0.165
# item: ('spaghetti sauce', 'cheeses') , 0.165
# item: ('paper towels', 'lunch meat') , 0.165
# item: ('poultry', 'ketchup') , 0.165
# item: ('cereals', 'ice cream') , 0.166
# item: ('soap', 'lunch meat') , 0.166
# item: ('aluminum foil', 'cereals') , 0.166
# item: ('dinner rolls', 'yogurt') , 0.166
# item: ('paper towels', 'eggs') , 0.166
# item: ('laundry detergent', 'milk') , 0.166
# item: ('toilet paper', 'cereals') , 0.166
# item: ('butter', 'poultry') , 0.166
# item: ('aluminum foil', 'dinner rolls') , 0.166
# item: ('fruits', 'beef') , 0.166
# item: ('soda', 'individual meals') , 0.166
# item: ('eggs', 'ketchup') , 0.166
# item: ('soap', 'ice cream') , 0.167
# item: ('coffee/tea', 'lunch meat') , 0.167
# item: ('spaghetti sauce', 'cereals') , 0.167
# item: ('bagels', 'spaghetti sauce') , 0.167
# item: ('soda', 'yogurt') , 0.167
# item: ('eggs', 'soap') , 0.167
# item: ('juice', 'ice cream') , 0.167
# item: ('yogurt', 'all- purpose') , 0.167
# item: ('waffles', 'poultry') , 0.167
# item: ('soda', 'dishwashing liquid/detergent') , 0.167
# item: ('juice', 'waffles') , 0.167
# item: ('eggs', 'ice cream') , 0.167
# item: ('milk', 'yogurt') , 0.168
# item: ('dinner rolls', 'cheeses') , 0.168
# item: ('fruits', 'dishwashing liquid/detergent') , 0.168
# item: ('bagels', 'poultry') , 0.168
# item: ('fruits', 'poultry') , 0.168
# item: ('coffee/tea', 'cheeses') , 0.168
# item: ('toilet paper', 'cheeses') , 0.168
# item: ('bagels', 'fruits') , 0.168
# item: ('waffles', 'all- purpose') , 0.168
# item: ('bagels', 'eggs') , 0.168
# item: ('pasta', 'ice cream') , 0.168
# item: ('soda', 'spaghetti sauce') , 0.168
# item: ('bagels', 'dishwashing liquid/detergent') , 0.168
# item: ('bagels', 'cheeses') , 0.168
# item: ('lunch meat', 'cereals') , 0.169
# item: ('milk', 'eggs') , 0.169
# item: ('beef', 'cereals') , 0.169
# item: ('lunch meat', 'spaghetti sauce') , 0.169
# item: ('soda', 'cheeses') , 0.169
# item: ('soda', 'ice cream') , 0.169
# item: ('aluminum foil', 'bagels') , 0.169
# item: ('pasta', 'eggs') , 0.169
# item: ('sandwich bags', 'cheeses') , 0.169
# item: ('eggs', 'waffles') , 0.169
# item: ('aluminum foil', 'waffles') , 0.169
# item: ('dinner rolls', 'shampoo') , 0.169
# item: ('laundry detergent', 'cereals') , 0.169
# item: ('coffee/tea', 'cereals') , 0.169
# item: ('eggs', 'cheeses') , 0.169
# item: ('aluminum foil', 'cheeses') , 0.169
# item: ('pasta', 'soda') , 0.169
# item: ('cereals', 'dishwashing liquid/detergent') , 0.169
# item: ('dinner rolls', 'waffles') , 0.169
# item: ('milk', 'dishwashing liquid/detergent') , 0.170
# item: ('individual meals', 'poultry') , 0.170
# item: ('beef', 'poultry') , 0.170
# item: ('paper towels', 'ice cream') , 0.170
# item: ('juice', 'shampoo') , 0.170
# item: ('spaghetti sauce', 'poultry') , 0.171
# item: ('shampoo', 'poultry') , 0.171
# item: ('eggs', 'dishwashing liquid/detergent') , 0.171
# item: ('dinner rolls', 'cereals') , 0.171
# item: ('tortillas', 'poultry') , 0.171
# item: ('soda', 'dinner rolls') , 0.171
# item: ('toilet paper', 'poultry') , 0.171
# item: ('juice', 'toilet paper') , 0.172
# item: ('aluminum foil', 'juice') , 0.172
# item: ('sandwich bags', 'poultry') , 0.172
# item: ('dinner rolls', 'spaghetti sauce') , 0.172
# item: ('yogurt', 'cheeses') , 0.172
# item: ('yogurt', 'cereals') , 0.172
# item: ('juice', 'spaghetti sauce') , 0.172
# item: ('coffee/tea', 'waffles') , 0.172
# item: ('aluminum foil', 'mixes') , 0.172
# item: ('soap', 'waffles') , 0.173
# item: ('pasta', 'dinner rolls') , 0.173
# item: ('waffles', 'cheeses') , 0.173
# item: ('soda', 'poultry') , 0.173
# item: ('waffles', 'ice cream') , 0.173
# item: ('soda', 'milk') , 0.173
# item: ('toilet paper', 'waffles') , 0.173
# item: ('lunch meat', 'ice cream') , 0.174
# item: ('eggs', 'dinner rolls') , 0.174
# item: ('yogurt', 'waffles') , 0.174
# item: ('milk', 'cereals') , 0.174
# item: ('cereals', 'mixes') , 0.174
# item: ('lunch meat', 'dishwashing liquid/detergent') , 0.174
# item: ('coffee/tea', 'poultry') , 0.175
# item: ('soda', 'soap') , 0.175
# item: ('eggs', 'yogurt') , 0.175
# item: ('eggs', 'cereals') , 0.175
# item: ('laundry detergent', 'poultry') , 0.175
# item: ('cheeses', 'cereals') , 0.175
# item: ('poultry', 'all- purpose') , 0.176
# item: ('waffles', 'dishwashing liquid/detergent') , 0.176
# item: ('aluminum foil', 'poultry') , 0.176
# item: ('aluminum foil', 'yogurt') , 0.176
# item: ('aluminum foil', 'ice cream') , 0.176
# item: ('juice', 'yogurt') , 0.176
# item: ('eggs', 'poultry') , 0.176
# item: ('juice', 'poultry') , 0.176
# item: ('soda', 'waffles') , 0.177
# item: ('individual meals', 'lunch meat') , 0.177
# item: ('milk', 'poultry') , 0.178
# item: ('cheeses', 'ice cream') , 0.179
# item: ('sugar', 'poultry') , 0.179
# item: ('poultry', 'ice cream') , 0.179
# item: ('dishwashing liquid/detergent', 'mixes') , 0.180
# item: ('yogurt', 'poultry') , 0.181
# item: ('poultry', 'cereals') , 0.181
# item: ('cheeses', 'poultry') , 0.181
# item: ('poultry', 'mixes') , 0.182
# item: ('soap', 'poultry') , 0.183
# item: ('waffles', 'lunch meat') , 0.184
# item: ('lunch meat', 'poultry') , 0.186
# item: ('poultry', 'dishwashing liquid/detergent') , 0.187
# item: ('soda', 'eggs') , 0.187
# item: ('dinner rolls', 'poultry') , 0.195
# item: ('vegetables', 'hand soap') , 0.270
# item: ('vegetables', 'pork') , 0.270
# item: ('vegetables', 'flour') , 0.277
# item: ('vegetables', 'sandwich loaves') , 0.283
# item: ('vegetables', 'tortillas') , 0.284
# item: ('vegetables', 'butter') , 0.284
# item: ('vegetables', 'individual meals') , 0.285
# item: ('pasta', 'vegetables') , 0.286
# item: ('vegetables', 'shampoo') , 0.288
# item: ('vegetables', 'all- purpose') , 0.290
# item: ('vegetables', 'coffee/tea') , 0.290
# item: ('vegetables', 'toilet paper') , 0.290
# item: ('paper towels', 'vegetables') , 0.290
# item: ('vegetables', 'fruits') , 0.291
# item: ('vegetables', 'ketchup') , 0.291
# item: ('vegetables', 'beef') , 0.291
# item: ('vegetables', 'sandwich bags') , 0.293
# item: ('juice', 'vegetables') , 0.294
# item: ('vegetables', 'soap') , 0.295
# item: ('vegetables', 'mixes') , 0.296
# item: ('vegetables', 'milk') , 0.296
# item: ('vegetables', 'spaghetti sauce') , 0.297
# item: ('vegetables', 'sugar') , 0.298
# item: ('vegetables', 'bagels') , 0.300
# item: ('vegetables', 'ice cream') , 0.303
# item: ('vegetables', 'soda') , 0.306
# item: ('vegetables', 'dishwashing liquid/detergent') , 0.306
# item: ('vegetables', 'dinner rolls') , 0.308
# item: ('vegetables', 'laundry detergent') , 0.309
# item: ('vegetables', 'cheeses') , 0.309
# item: ('vegetables', 'cereals') , 0.311
# item: ('aluminum foil', 'vegetables') , 0.311
# item: ('vegetables', 'lunch meat') , 0.312
# item: ('vegetables', 'waffles') , 0.315
# item: ('vegetables', 'yogurt') , 0.319
# item: ('vegetables', 'eggs') , 0.327
# item: ('vegetables', 'poultry') , 0.332
# item: ('hand soap',) , 0.346
# item: ('sandwich loaves',) , 0.349
# item: ('flour',) , 0.353
# item: ('pork',) , 0.356
# item: ('sugar',) , 0.361
# item: ('paper towels',) , 0.363
# item: ('butter',) , 0.368
# item: ('sandwich bags',) , 0.368
# item: ('shampoo',) , 0.369
# item: ('tortillas',) , 0.370
# item: ('fruits',) , 0.371
# item: ('ketchup',) , 0.371
# item: ('pasta',) , 0.371
# item: ('spaghetti sauce',) , 0.373
# item: ('beef',) , 0.375
# item: ('all- purpose',) , 0.375
# item: ('mixes',) , 0.376
# item: ('individual meals',) , 0.376
# item: ('juice',) , 0.377
# item: ('toilet paper',) , 0.378
# item: ('laundry detergent',) , 0.378
# item: ('coffee/tea',) , 0.379
# item: ('soap',) , 0.379
# item: ('milk',) , 0.380
# item: ('yogurt',) , 0.384
# item: ('aluminum foil',) , 0.385
# item: ('bagels',) , 0.385
# item: ('dishwashing liquid/detergent',) , 0.388
# item: ('dinner rolls',) , 0.389
# item: ('eggs',) , 0.390
# item: ('cheeses',) , 0.391
# item: ('soda',) , 0.391
# item: ('waffles',) , 0.394
# item: ('lunch meat',) , 0.395
# item: ('cereals',) , 0.396
# item: ('ice cream',) , 0.399
# item: ('poultry',) , 0.421
# item: ('vegetables',) , 0.739
#
# ------------RULES-----------------
# Rule: ('eggs', 'sandwich loaves') ==> ('vegetables',) , 0.902

# %% [markdown]
# ## Report
# (separately in pdf)

# %% [markdown]
# Take a small dataset (it can be any dataset). Show 3 support and confidence for the small dataset. Show the rules for all the 3 cases using the formula.
# Provide references where ever necessary.

# %% [markdown]
# # References
#
# [01] https://www.kaggle.com/acostasg/random-shopping-cart
#
# [02] https://github.com/asaini/Apriori

# %% [markdown]
# # Rubric
# * [02 points] - Student Details
# * [08 points] - Comply with submission instructions
# * [30 points] - DataSet Preprocess
# * [30 points] - Run apriory.py
# * [5 points] - Evaluate Results
# * [25 points] - Report
